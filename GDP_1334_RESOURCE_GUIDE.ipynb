# %% [markdown]
# # TITLE: RESOURCE GUIDE:

# %% [markdown]
# ## Module & Library Import

# %%
    # 1 Data manipulation
import numpy as np
from bs4 import BeautifulSoup as bs
import pandas as pd
import pandas_datareader
from pandas_datareader import data as web
    # 7 Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

    # 11 Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
    # 14 More Visualizations
import chart_studio.plotly as py
import plotly
import plotly.tools as tls
import plotly.graph_objs as go
import plotly.offline as ply
plotly.offline.init_notebook_mode(connected=True)
    # 21 Cufflinks binds Plotly directly to pandas dataframes.
import cufflinks as cf
cf.go_offline(connected=True)
cf.set_config_file(theme='white')
 
    # 26 IMPORT API FUNCTIONS
import quandl
import yfinance as yf
from yahoofinancials import YahooFinancials
import requests
import alpha_vantage
from alpha_vantage.timeseries import TimeSeries
import iex
import iexfinance
from iexfinance.stocks import Stock
from iexfinance.stocks import get_historical_data
from iexfinance.stocks import get_historical_intraday
from iexfinance.refdata import get_symbols
from iexfinance.data_apis import get_data_points
from iexfinance.data_apis import get_time_series
from iexfinance.altdata import get_social_sentiment
from iexfinance.altdata import get_ceo_compensation

    # 44 MISC LIB IMPORTS
import locale
from datetime import date, datetime
from nsepy import get_history
import os
import time
import csv
import json
from patsy import dmatrices

    # 54

# %% [markdown]
# ## Local library import
# We import all the required local libraries libraries

# %%
# Include local library paths
import sys

    # uncomment and fill to import local libraries
    
# sys.path.append('path/to/local/lib') 
# Import local libraries

# %% [markdown]
# # References
#
# * import jupytemplate
# * print(jupytemplate.get_template_path())

# %% [markdown]
# # GENERAL TRICKS:

# %% [markdown]
# ## Format Outputs
# * ADD COMMAS TO NUMBERS

# %%
    # ADD COMMAS TO NUMBERS\

value=100000000000000000
    
print('$'+f'{value:,}')


print('ANNUAL_NON-DIVERSIFIABLE RISK = ' + f'{value:%}')
# Out:
# $100,000,000,000,000,000
# ANNUAL_NON-DIVERSIFIABLE RISK = 10000000000000000000.000000%

# %% [markdown]
# # Data import
# * We retrieve all the required data for the analysis.

# %% [markdown]
# ## save data

# %%
data.to_csv(r'C:\Users\gordo\Programming\Data_Bank\New_bank\_'+stocks+'.csv')
            
data.to_excel(r'C:\Users\gordo\Programming\Data_Bank\New_bank\_'+stocks+'.xlsx')

# %% [markdown]
# ## NASDAQ

# %%
# Get the list of all available equity symbols from Nasdaq.

    # Returns nasdaq_tickers – 
        # DataFrame with company tickers, names, and other properties.
    # Return type pandas.DataFrame

pd.nasdaq_trader.get_nasdaq_symbols(retry_count=3, timeout=30,
                                    pause=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1860e15c4f22> in <module>
#       5     # Return type pandas.DataFrame
#       6
# ----> 7 pd.nasdaq_trader.get_nasdaq_symbols(retry_count=3, timeout=30,
#       8                                     pause=None)
#       9
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## INTRINO

# %%
import intrinio_sdk
import pandas as pd

intrinio_sdk.ApiClient().configuration.api_key['api_key'] = '{OjdlOTlkZjdkODk3MDY0YzkzMWMxZDM0NjIyZTMyZTYw}' 
security_api = intrinio_sdk.SecurityApi()

# %%
r = security_api.get_security_stock_prices(identifier='AAPL',
                                           start_date='2000-01-01',
                                           end_date='2010-12-31',
                                           frequency='daily',
                                           page_size=10000)
r=pd.DataFrame(r)
r

# %%
response_list = [x.to_dict() for x in r.stock_prices]
df_intrinio = pd.DataFrame(response_list).sort_values('date')
df_intrinio.set_index('date', inplace=True)

# %% [markdown]
# ## quandl
# Quandl has many data sources to get different types of data. However, some are free and some are paid. Wiki is the free data source of Quandl to get the data of the end of the day prices of 3000+ US equities.
#
# It is curated by Quandl community and also provides information about the dividends and split.
#
# To get the stock market data, you need to first install the quandl module if it is not already installed using the pip command as shown below.
#
# ####  Advantages
# It is free of cost Has split and dividend-adjusted stock market data
#
# #### Disadvantages
# Only available till 27-March-2018

# %% [markdown]
# ### cookbook

# %%
import pandas as pd
import quandl

QUANDL_KEY = 'dbyBuiq4bczbbuz9bA4t'
quandl.ApiConfig.api_key = QUANDL_KEY

df_quandl = quandl.get(dataset='WIKI/AAPL',
                       start_date='2000-01-01',
                       end_date='2010-12-31',api_key=QUANDL_KEY)

df_quandl
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-10-1ddb358b61d1> in <module>
#       5 quandl.ApiConfig.api_key = QUANDL_KEY
#       6
# ----> 7 df_quandl = quandl.get(dataset='WIKI/ACEL',
#       8                        start_date='2000-01-01',
#       9                        end_date='2010-12-31',api_key=QUANDL_KEY)
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\operations\list.py in all(cls, **options)
#      13             options['params'] = {}
#      14         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15         r = Connection.request('get', path, **options)
#      16         response_data = r.json()
#      17         Util.convert_to_dates(response_data)
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\connection.py in request(cls, http_verb, url, **options)
#      36         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      37
# ---> 38         return cls.execute_request(http_verb, abs_url, **options)
#      39
#      40     @classmethod
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\connection.py in execute_request(cls, http_verb, url, **options)
#      48                                        **options)
#      49             if response.status_code < 200 or response.status_code >= 300:
# ---> 50                 cls.handle_api_error(response)
#      51             else:
#      52                 return response
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\connection.py in handle_api_error(cls, resp)
#     112         klass = d_klass.get(code_letter, QuandlError)
#     113
# --> 114         raise klass(message, resp.status_code, resp.text, resp.headers, code)
#
# NotFoundError: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.

# %% [markdown]
# ### other data pulls

# %%
QUANDL_API_KEY = 'dbyBuiq4bczbbuz9bA4t'

# Set the start and end date
start_date = '1990-01-01'
end_date = '2018-03-01'

# Set the ticker name
ticker = 'AMZN'

# Feth the data
data = quandl.get('WIKI/'+ticker, start_date=start_date,
                  end_date=end_date, api_key=QUANDL_API_KEY)

# Print the first 5 rows of the dataframe
data.head()

# %%
# Define the figure size for the plot
plt.figure(figsize=(10, 7))

# Plot the adjusted close price
data['Adj. Close'].plot()

# Define the label for the title of the figure
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# ### multi security pull

# %%
# Define the ticker list
tickers_list = ['AAPL', 'IBM', 'MSFT', 'WMT']

# Import pandas
data = pd.DataFrame(columns=tickers_list)

# Feth the data
for ticker in tickers_list:
    data[ticker] = quandl.get('WIKI/' + ticker, start_date=start_date,
                              end_date=end_date, api_key=QUANDL_API_KEY)['Adj. Close']

# Print first 5 rows of the data
data.head()

# %%
# Plot all the close prices
data.plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Adjusted Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
pd.quandl.QuandlReader(symbols, start=None, end=None,
                       retry_count=3, pause=0.1,
                       session=None,chunksize=25,
                       api_key=None)

# %%
# Returns DataFrame of historical stock prices from symbol, 
    # over date range, start to end.

pd.quandl.QuandlReader(symbols, start=None, end=None,
                       retry_count=3, pause=0.1, session=None,
                       chunksize=25, api_key=None)

# %% [markdown]
# ### main pulls

# %%
# QUANDL API FIXED-PARAMETERS

quandl.ApiConfig.api_key = 'VpYKj-e3pTXsUxQBMcto'


start_date=('2018-1-1')
end_date=('2020-1-1')

# %%
# SPECIFIC_DATE

SPECIFIC_DATE=quandl.get('FINRA/FORF_TLLTD', start_date='2018-06-22', end_date='2018-06-22')
SPECIFIC_DATE

# %%
# FILTER BY DATE_RANGE

DATE_RANGE=quandl.get('FINRA/FORF_TLLTD', start_date='2018-06-14', end_date='2018-06-22')
DATE_RANGE

# %%
# RETRIEVE Two_Columns

Two_Columns=quandl.get('FINRA/FORF_TLLTD', start_date=start_date, end_date=end_date, column_index='1')
Two_Columns

# %%
# RETRIEVE UNFILTERED TIME-SERIES

UNFILTERED=quandl.get('FINRA/FORF_TLLTD')
UNFILTERED

# %% [markdown]
# ### (ZEFR)
# * Zacks Expanded Fundamental Ratios

# %%
# Exp Ratio F1 (Exp_Ratio_F1)

Exp_Ratio_F1 = quandl.get_table("ZACKS/RF1", paginate=True)
Exp_Ratio_F1

# %%
# Exp Ratio F160 
# Exp_Ratio_F160

Exp_Ratio_F160= quandl.get_table("ZACKS/RF160", paginate=True)
Exp_Ratio_F160

# %% [markdown]
# ###  - Z_A_R
# * Zacks Analyst Revisions

# %%
    # Zacks Earnings Estimate Revisions
        # Z_Earning_Est_Rev

Z_Earning_Est_Rev = quandl.get_table("ZACKS/EREV", paginate=True)
Z_Earning_Est_Rev

# %% [markdown]
# ### Zacks Sales Surprises

# %%
# Zacks Master Table
    # Z_Master

Z_Master = quandl.get_table("ZACKS/MT", paginate=True)
Z_Master

# %%
# Zacks Sales Surprises
    # Z_Sales

Z_Sales = quandl.get_table("ZACKS/SS", paginate=True)
Z_Sales

# %% [markdown]
# ### Zacks Fundamentals Collection C

# %%
# Zacks Master Table
    # Z_Master_c
    
Z_Master_c=data = quandl.get_table("ZACKS/MT", paginate=True)
Z_Master_c

# %%
# Zacks Fundamental Ratios
    # Z_Fund_Ratio_c
    
Z_Fund_Ratio_c=quandl.get_table("ZACKS/FR", paginate=True)
Z_Fund_Ratio_c

# %%
# Zacks Fundamentals Expanded
    # Z_Fund_Exp_C
    
Z_Fund_Exp_C=quandl.get_table("ZACKS/FE", paginate=True)
Z_Fund_Exp_C

# %% [markdown]
# ### Zacks Fundamentals Collection B

# %%
# Zacks Fundamentals Condensed
    #Z_F_C_B

Z_F_C_B = quandl.get_table("ZACKS/FC", paginate=True)
Z_F_C_B

# %%
# Zacks Fundamental Ratios
    # Z_F_R_B
    
Z_F_R_B = quandl.get_table("ZACKS/FR", paginate=True)
Z_F_R_B

# %%
# Zacks Master Table
    # Z_M_T_B
    
Z_M_T_B = quandl.get_table("ZACKS/MT", paginate=True)
Z_M_T_B

# %% [markdown]
# ### Zacks Fundamentals Collection A

# %%
# Zacks Fundamentals Condensed
    # Z_F_C_A
    
Z_F_C_A = quandl.get_table("ZACKS/FC", paginate=True)
Z_F_C_A

# %%
# Zacks Fundamental Ratios
    # Z_F_R_A
    
Z_F_R_A = quandl.get_table("ZACKS/FR", paginate=True)
Z_F_R_A

# %%
# Zacks Master Table
    # Z_M_T_A
    
Z_M_T_A = quandl.get_table("ZACKS/MT", paginate=True)
Z_M_T_A

# %% [markdown]
# ### Sharadar Core US Equities Bundle

# %%
# Core US Fundamentals
    # Core_US_Fundamentals
    
Core_US_Fundamentals = quandl.get_table("SHARADAR/SF1", paginate=True)
Core_US_Fundamentals

# %%
# Tickers and Metadata
    # TIX_META
    
TIX_META = quandl.get_table("SHARADAR/TICKERS", paginate=True)
TIX_META

# %% [markdown]
# ## IEX
# * https://addisonlynch.github.io/iexfinance/stable/index.html
# * pd.iex.daily.IEXDailyReader(symbols=None, start=None,end=None, retry_count=3,pause=0.1, session=None, chunksize=25, api_key=None)

# %% [markdown]
# ### GENERAL:

# %% [markdown]
# #### Passing as an Argument I.

# %%
from iexfinance.refdata import get_symbols

get_symbols(output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')

a = Stock('TICKER', token='pk_b740ad24ded147cca822e98ded174c3d')

# %% [markdown]
# #### Passing as an Argument II.

# %%
from iexfinance.stocks import Stock

a = Stock('AAPL', token='pk_b740ad24ded147cca822e98ded174c3d')
a.get_quote()

# %% [markdown]
# ####  FORMATTING FOR PULLS:

# %%
start = datetime(2016, 9, 1)
end = datetime(2018, 9, 1)

IEX_API_KEY='pk_b740ad24ded147cca822e98ded174c3d'


f = web.DataReader('F', 'iex', start, end, api_key=IEX_API_KEY)

# %% [markdown]
# #### Fetch all stock symbols
# * Returns a Pandas Dataframe of all stock symbols, names, and more.
# * iexfinance.refdata.get_symbols(**kwargs)

# %%
from iexfinance.refdata import get_symbols
get_symbols(token='pk_b740ad24ded147cca822e98ded174c3d')[:2]
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2020-02-29',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AA',
#   'exchange': 'NYS',
#   'name': 'Alcoa Corp.',
#   'date': '2020-02-29',
#   'type': 'cs',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True}]

# %%
from iexfinance.refdata import get_symbols

get_symbols(output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')
# Out:
#      symbol exchange                                 name        date type  \
# 0         A      NYS            Agilent Technologies Inc.  2020-02-29   cs
# 1        AA      NYS                          Alcoa Corp.  2020-02-29   cs
# 2      AAAU      PSE         Perth Mint Physical Gold ETF  2020-02-29   et
# 3      AACG      NAS  ATA Creativity Global Sponsored ADR  2020-02-29   ad
# 4      AADR      PSE  AdvisorShares Dorsey Wright ADR ETF  2020-02-29   et
# ...     ...      ...                                  ...         ...  ...
# 8862    ZUO      NYS                   Zuora Inc. Class A  2020-02-29   cs
# 8863    ZVO      NAS                           Zovio Inc.  2020-02-29   cs
# 8864   ZYME      NYS                       Zymeworks Inc.  2020-02-29   cs
# 8865   ZYNE      NAS          Zynerba Pharmaceuticals Inc  2020-02-29   cs
# 8866   ZYXI      NAS                           Zynex Inc.  2020-02-29   cs
#
#                      iexId region currency  isEnabled
# 0     IEX_46574843354B2D52     US      USD       True
# 1     IEX_4238333734532D52     US      USD       True
# 2     IEX_474B433136332D52     US      USD       True
# 3     IEX_44595A4C53392D52     US      USD       True
# 4     IEX_5253355435362D52     US      USD       True
# ...                    ...    ...      ...        ...
# 8862  IEX_4D474631525A2D52     US      USD       True
# 8863  IEX_514A435352362D52     US      USD       True
# 8864  IEX_5253315838322D52     US      USD       True
# 8865  IEX_4E3154424A382D52     US      USD       True
# 8866  IEX_4E464C4C4A462D52     US      USD       True
#
# [8867 rows x 9 columns]

# %%
from iexfinance.stocks import Stock

aapl = Stock("AAPL", output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')
aapl.get_quote().head()
# Out:
#                       AAPL
# avgTotalVolume    38319408
# calculationPrice     close
# change               -0.16
# changePercent     -0.00058
# close               273.36

# %% [markdown]
# ###  Available Data Points For a Symbol
# * To obtain all available data points for a symbol, simply pass the symbol to get_data_points with no key:

# %%
from iexfinance.data_apis import get_data_points

data_pts=(get_data_points("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d'))
data_pts
# Out:
# [{'key': 'NEXTDIVIDENDDATE',
#   'weight': 1,
#   'description': '',
#   'lastUpdated': '2020-02-07T16:24:55+00:00'},
#  {'key': 'ACCOUNTSPAYABLE',
#   'weight': 3000,
#   'description': 'Balance Sheet: accountsPayable',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CAPITALSURPLUS',
#   'weight': 3000,
#   'description': 'Balance Sheet: capitalSurplus',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'COMMONSTOCK',
#   'weight': 3000,
#   'description': 'Balance Sheet: commonStock',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CURRENTASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: currentAssets',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CURRENTCASH',
#   'weight': 3000,
#   'description': 'Balance Sheet: currentCash',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CURRENTLONGTERMDEBT',
#   'weight': 3000,
#   'description': 'Balance Sheet: currentLongTermDebt',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'GOODWILL',
#   'weight': 3000,
#   'description': 'Balance Sheet: goodwill',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'INTANGIBLEASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: intangibleAssets',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'INVENTORY',
#   'weight': 3000,
#   'description': 'Balance Sheet: inventory',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'LONGTERMDEBT',
#   'weight': 3000,
#   'description': 'Balance Sheet: longTermDebt',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'LONGTERMINVESTMENTS',
#   'weight': 3000,
#   'description': 'Balance Sheet: longTermInvestments',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'NETTANGIBLEASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: netTangibleAssets',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OTHERASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherAssets',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OTHERCURRENTASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherCurrentAssets',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OTHERCURRENTLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherCurrentLiabilities',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OTHERLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherLiabilities',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'PROPERTYPLANTEQUIPMENT',
#   'weight': 3000,
#   'description': 'Balance Sheet: propertyPlantEquipment',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'RECEIVABLES',
#   'weight': 3000,
#   'description': 'Balance Sheet: receivables',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'RETAINEDEARNINGS',
#   'weight': 3000,
#   'description': 'Balance Sheet: retainedEarnings',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'SHAREHOLDEREQUITY',
#   'weight': 3000,
#   'description': 'Balance Sheet: shareholderEquity',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'SHORTTERMINVESTMENTS',
#   'weight': 3000,
#   'description': 'Balance Sheet: shortTermInvestments',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'TOTALASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: totalAssets',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'TOTALCURRENTLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: totalCurrentLiabilities',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'TOTALLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: totalLiabilities',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'TREASURYSTOCK',
#   'weight': 3000,
#   'description': 'Balance Sheet: treasuryStock',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CAPITALEXPENDITURES',
#   'weight': 1000,
#   'description': 'Cash Flow: capitalExpenditures',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CASHCHANGE',
#   'weight': 1000,
#   'description': 'Cash Flow: cashChange',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CASHFLOW',
#   'weight': 1000,
#   'description': 'Cash Flow: cashFlow',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CASHFLOWFINANCING',
#   'weight': 1000,
#   'description': 'Cash Flow: cashFlowFinancing',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CHANGESININVENTORIES',
#   'weight': 1000,
#   'description': 'Cash Flow: changesInInventories',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CHANGESINRECEIVABLES',
#   'weight': 1000,
#   'description': 'Cash Flow: changesInReceivables',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'DEPRECIATION',
#   'weight': 1000,
#   'description': 'Cash Flow: depreciation',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'DIVIDENDSPAID',
#   'weight': 1000,
#   'description': 'Cash Flow: dividendsPaid',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'EXCHANGERATEEFFECT',
#   'weight': 1000,
#   'description': 'Cash Flow: exchangeRateEffect',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'INVESTINGACTIVITYOTHER',
#   'weight': 1000,
#   'description': 'Cash Flow: investingActivityOther',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'INVESTMENTS',
#   'weight': 1000,
#   'description': 'Cash Flow: investments',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'NETBORROWINGS',
#   'weight': 1000,
#   'description': 'Cash Flow: netBorrowings',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OTHERFINANCINGCASHFLOWS',
#   'weight': 1000,
#   'description': 'Cash Flow: otherFinancingCashFlows',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'TOTALINVESTINGCASHFLOWS',
#   'weight': 1000,
#   'description': 'Cash Flow: totalInvestingCashFlows',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'EBITDA',
#   'weight': 500,
#   'description': 'EBITDA',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'COSTOFREVENUE',
#   'weight': 1000,
#   'description': 'Income Statement: costOfRevenue',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'CURRENCY',
#   'weight': 1000,
#   'description': 'Income Statement: currency',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'EBIT',
#   'weight': 1000,
#   'description': 'Income Statement: ebit',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'FISCALDATE',
#   'weight': 1000,
#   'description': 'Income Statement: fiscalDate',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'INCOMETAX',
#   'weight': 1000,
#   'description': 'Income Statement: incomeTax',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'INTERESTINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: interestIncome',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'MINORITYINTEREST',
#   'weight': 1000,
#   'description': 'Income Statement: minorityInterest',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'NETINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: netIncome',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'NETINCOMEBASIC',
#   'weight': 1000,
#   'description': 'Income Statement: netIncomeBasic',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OPERATINGEXPENSE',
#   'weight': 1000,
#   'description': 'Income Statement: operatingExpense',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OPERATINGINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: operatingIncome',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'OTHERINCOMEEXPENSENET',
#   'weight': 1000,
#   'description': 'Income Statement: otherIncomeExpenseNet',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'PRETAXINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: pretaxIncome',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'REPORTDATE',
#   'weight': 1000,
#   'description': 'Income Statement: reportDate',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'RESEARCHANDDEVELOPMENT',
#   'weight': 1000,
#   'description': 'Income Statement: researchAndDevelopment',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'SELLINGGENERALANDADMIN',
#   'weight': 1000,
#   'description': 'Income Statement: sellingGeneralAndAdmin',
#   'lastUpdated': '2020-03-01T04:02:01+00:00'},
#  {'key': 'LAST-DIVIDEND-AMOUNT',
#   'weight': 10,
#   'description': 'Last dividend amount',
#   'lastUpdated': '2020-02-29T20:30:43+00:00'},
#  {'key': 'LAST-DIVIDEND-EX-DATE',
#   'weight': 10,
#   'description': 'Last dividend ex date',
#   'lastUpdated': '2020-02-29T20:30:43+00:00'},
#  {'key': 'LAST-DIVIDEND-PAYMENT-DATE',
#   'weight': 10,
#   'description': 'Last dividend payment date',
#   'lastUpdated': '2020-02-29T20:30:43+00:00'},
#  {'key': 'COMPANY-LAST-UPDATED',
#   'weight': 0,
#   'description': 'Last update epoch for company endpoint',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'LATEST-FINANCIAL-ANNUAL-REPORT-DATE',
#   'weight': 0,
#   'description': 'Latest annual financials report date available',
#   'lastUpdated': '2020-03-01T04:03:43+00:00'},
#  {'key': 'LATEST-FINANCIAL-REPORT-DATE',
#   'weight': 0,
#   'description': 'Latest financials report date available',
#   'lastUpdated': '2020-03-01T04:03:43+00:00'},
#  {'key': 'LATEST-FINANCIAL-QUARTERLY-REPORT-DATE',
#   'weight': 0,
#   'description': 'Latest quarterly financials report date available',
#   'lastUpdated': '2020-02-29T08:11:34+00:00'},
#  {'key': 'PRICE-TARGET',
#   'weight': 500,
#   'description': 'Price target average',
#   'lastUpdated': '2020-02-29T21:00:21+00:00'},
#  {'key': 'QUOTE-CHANGE',
#   'weight': 1,
#   'description': 'Quote: change',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-CHANGEPERCENT',
#   'weight': 1,
#   'description': 'Quote: changePercent',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-CLOSE',
#   'weight': 1,
#   'description': 'Quote: close',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-CLOSETIME',
#   'weight': 1,
#   'description': 'Quote: closeTime',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-EXTENDEDCHANGE',
#   'weight': 1,
#   'description': 'Quote: extendedChange',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-EXTENDEDCHANGEPERCENT',
#   'weight': 1,
#   'description': 'Quote: extendedChangePercent',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-EXTENDEDPRICE',
#   'weight': 1,
#   'description': 'Quote: extendedPrice',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-HIGH',
#   'weight': 1,
#   'description': 'Quote: high',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-IEXVOLUME',
#   'weight': 1,
#   'description': 'Quote: iexVolume',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-LATESTPRICE',
#   'weight': 1,
#   'description': 'Quote: latestPrice',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-LATESTUPDATE',
#   'weight': 1,
#   'description': 'Quote: latestUpdate',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-LATESTVOLUME',
#   'weight': 1,
#   'description': 'Quote: latestVolume',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-LOW',
#   'weight': 1,
#   'description': 'Quote: low',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-MARKETCAP',
#   'weight': 1,
#   'description': 'Quote: marketCap',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-OPEN',
#   'weight': 1,
#   'description': 'Quote: open',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'QUOTE-OPENTIME',
#   'weight': 1,
#   'description': 'Quote: openTime',
#   'lastUpdated': '2020-03-01T04:25:08+00:00'},
#  {'key': 'LATEST-NEWS',
#   'weight': 0,
#   'description': 'Timestamp of the latest available news item',
#   'lastUpdated': '2020-02-29T23:40:02+00:00'},
#  {'key': 'ADDRESS',
#   'weight': 1,
#   'description': 'address',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'AVG10VOLUME',
#   'weight': 1,
#   'description': 'avg10Volume',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'AVG30VOLUME',
#   'weight': 1,
#   'description': 'avg30Volume',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'BETA',
#   'weight': 1,
#   'description': 'beta',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'CEO',
#   'weight': 1,
#   'description': 'ceo',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'CITY',
#   'weight': 1,
#   'description': 'city',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'COMPANYNAME',
#   'weight': 1,
#   'description': 'companyName',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'COUNTRY',
#   'weight': 1,
#   'description': 'country',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'CURRENTDEBT',
#   'weight': 500,
#   'description': 'currentDebt',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'DAY200MOVINGAVG',
#   'weight': 1,
#   'description': 'day200MovingAvg',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'DAY50MOVINGAVG',
#   'weight': 1,
#   'description': 'day50MovingAvg',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'DEBTTOEQUITY',
#   'weight': 500,
#   'description': 'debtToEquity',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'DIVIDENDYIELD',
#   'weight': 1,
#   'description': 'dividendYield',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'EMPLOYEES',
#   'weight': 1,
#   'description': 'employees',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'ENTERPRISEVALUE',
#   'weight': 500,
#   'description': 'enterpriseValue',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'ENTERPRISEVALUETOREVENUE',
#   'weight': 500,
#   'description': 'enterpriseValueToRevenue',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'EXCHANGE',
#   'weight': 1,
#   'description': 'exchange',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'FLOAT',
#   'weight': 1,
#   'description': 'float',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'FORWARDPERATIO',
#   'weight': 500,
#   'description': 'forwardPERatio',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'GROSSPROFIT',
#   'weight': 500,
#   'description': 'grossProfit',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'INDUSTRY',
#   'weight': 1,
#   'description': 'industry',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'ISSUETYPE',
#   'weight': 1,
#   'description': 'issuetype',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'LONGDESCRIPTION',
#   'weight': 1,
#   'description': 'longDescription',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'PEHIGH',
#   'weight': 500,
#   'description': 'peHigh',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'PELOW',
#   'weight': 500,
#   'description': 'peLow',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'PEGRATIO',
#   'weight': 500,
#   'description': 'pegRatio',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'PHONE',
#   'weight': 1,
#   'description': 'phone',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'PRICETOBOOK',
#   'weight': 500,
#   'description': 'priceToBook',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'PRICETOSALES',
#   'weight': 500,
#   'description': 'priceToSales',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'PROFITMARGIN',
#   'weight': 500,
#   'description': 'profitMargin',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'REVENUE',
#   'weight': 500,
#   'description': 'revenue',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'REVENUEPEREMPLOYEE',
#   'weight': 500,
#   'description': 'revenuePerEmployee',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'REVENUEPERSHARE',
#   'weight': 500,
#   'description': 'revenuePerShare',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'SECTOR',
#   'weight': 1,
#   'description': 'sector',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'SECURITYNAME',
#   'weight': 1,
#   'description': 'securityName',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'SHARESOUTSTANDING',
#   'weight': 1,
#   'description': 'sharesOutstanding',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'STATE',
#   'weight': 1,
#   'description': 'state',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'TOTALCASH',
#   'weight': 500,
#   'description': 'totalCash',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'TOTALREVENUE',
#   'weight': 500,
#   'description': 'totalRevenue',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'TTMDIVIDENDRATE',
#   'weight': 1,
#   'description': 'ttmDividendRate',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'TTMEPS',
#   'weight': 1,
#   'description': 'ttmEPS',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'WEBSITE',
#   'weight': 1,
#   'description': 'website',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'WEEK52CHANGE',
#   'weight': 1,
#   'description': 'week52change',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'WEEK52HIGH',
#   'weight': 1,
#   'description': 'week52high',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'WEEK52HIGHDATE',
#   'weight': 500,
#   'description': 'week52highDate',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'WEEK52LOW',
#   'weight': 1,
#   'description': 'week52low',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'},
#  {'key': 'WEEK52LOWDATE',
#   'weight': 500,
#   'description': 'week52lowDate',
#   'lastUpdated': '2020-03-01T04:15:36+00:00'},
#  {'key': 'ZIP',
#   'weight': 1,
#   'description': 'zip',
#   'lastUpdated': '2020-03-01T04:09:10+00:00'}]

# %% [markdown]
# ####  Individual Data Points For a Symbol
# * To obtain an individual data point for a single symbol, pass the symbol and the data point ID to get_data_points:

# %%
import locale
from iexfinance.data_apis import get_data_points

data_pts1=get_data_points('AAPL', 'NETINCOME', token = 'pk_3e46a4b55bd04bd68bb778802602595b')

print('$'+f'{data_pts1:,}')
# Out:
# $53,394,000,000

# %% [markdown]
# ####  All Available Time Series
# * To obtain a list of all available time series, simply call get_time_series with no parameters:

# %%
from iexfinance.data_apis import get_time_series

get_time_series(token = 'pk_3e46a4b55bd04bd68bb778802602595b')
# Out:
# [{'id': 'PREMIUM_WALLSTREETHORIZON_OPTION_EXPIRATION_DATE',
#   'description': 'Company Events (Option Expiration Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'optionSymbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'usStockExchange': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'expirationDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'expirationFrequency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'strikeStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'optionType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_OPTION_EXPIRATION_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:16',
#   'lastUpdated': '2019-10-14 18:04:16'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_WITCHING_HOURS',
#   'description': 'Calendar Events (Witching hours)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDay': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'financialCenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_WITCHING_HOURS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:19',
#   'lastUpdated': '2019-10-14 18:04:19'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_FILING_DUE_DATE',
#   'description': 'Company Events (Filing Due Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'filingDueDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarter': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYear': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_FILING_DUE_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:17',
#   'lastUpdated': '2019-10-14 18:04:17'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_BUYBACK',
#   'description': 'Dividend Events (Buyback)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'buybackStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'buybackMethod': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'approvalDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'numberOfShares': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'sharesDifferent': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'percentOfShares': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'shareValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'shareValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'valueDifferent': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'priceFrom': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'priceTo': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'tenderResult': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'tenderExpiration': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'newsReferences': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNotes': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_BUYBACK',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:00',
#   'lastUpdated': '2019-10-14 18:04:00'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_PRODUCT_EVENTS',
#   'description': 'Product Events (Product Events)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'releaseDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'releaseTitle': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'region': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'distributor': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'accuracy': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_PRODUCT_EVENTS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:15',
#   'lastUpdated': '2019-10-14 18:04:15'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_GENERAL_CONFERENCE',
#   'description': 'Conference Events (General Conference)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_GENERAL_CONFERENCE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:03',
#   'lastUpdated': '2019-10-14 18:04:03'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_STOCK_SPECIFIC_FDA_ADVISORY_COMMITTEE_MEETING',
#   'description': 'Government Events (Stock Specific FDA Advisory Committee meeting)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_STOCK_SPECIFIC_FDA_ADVISORY_COMMITTEE_MEETING',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:00',
#   'lastUpdated': '2019-10-14 18:04:00'},
#  {'id': 'ADVANCED_RIGHTS_TO_PURCHASE',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'symbol': {'type': 'string'}},
#    'required': ['symbol'],
#    'additionalProperties': True},
#   'weightKey': 'ADVANCED_RIGHTS_TO_PURCHASE',
#   'weight': 0,
#   'created': '2019-11-25 14:26:55',
#   'lastUpdated': '2019-11-25 14:26:55'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_HOLIDAYS',
#   'description': 'Calendar Events (holidays)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDay': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'earlyCloseTime': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'countryCode': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'financialCenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_HOLIDAYS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:18',
#   'lastUpdated': '2019-10-14 18:04:18'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_FISCAL_QUARTER_END_DATE',
#   'description': 'Company Events (Fiscal quarter End Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarterEndDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarter': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYear': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_FISCAL_QUARTER_END_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:16',
#   'lastUpdated': '2019-10-14 18:04:16'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_LEGAL_ACTIONS',
#   'description': 'Legal/Activist (Legal actions)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'caseDescription': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactEmail': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'caseUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactName': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'lawfirm': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'category': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactPhone': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'lawfirmHomepage': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'classPeriodBegin': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'motionDeadline': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'classPeriodEnd': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'prUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'stage': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_LEGAL_ACTIONS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:14',
#   'lastUpdated': '2019-10-14 18:04:14'},
#  {'id': 'ADVANCED_DISTRIBUTION',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'electionDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fromFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'hasWithdrawalRights': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'maxPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'minPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'ratio': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'toFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'withdrawalFromDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'withdrawalToDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_DISTRIBUTION',
#   'weight': 75000,
#   'created': '2019-11-25 14:19:27',
#   'lastUpdated': '2019-11-25 14:19:27'},
#  {'id': 'ADVANCED_RETURN_OF_CAPITAL',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'cashBack': {'anyOf': [{'type': 'number'},
#       {'type': 'null'}]},
#     'countryCode': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'electionDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'hasWithdrawalRights': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'withdrawalFromDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'withdrawalToDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_RETURN_OF_CAPITAL',
#   'weight': 75000,
#   'created': '2019-11-25 13:55:30',
#   'lastUpdated': '2019-11-25 13:55:30'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_RD_DAY',
#   'description': 'Analyst/Investor Events (RD Day)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_RD_DAY',
#   'weight': 1125000,
#   'created': '2019-10-14 19:10:37',
#   'lastUpdated': '2019-10-14 19:10:37'},
#  {'id': 'PREMIUM_BRAIN_RANKING_2_DAYS',
#   'description': 'The stock ranking according to Brain Machine Learning Model. Each stock is ranked by a score (or "alpha") related to the predicted future returns for the time horizon of 2 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'mlAlpha': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'daysForecast': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'compositeFigi',
#     'symbol',
#     'mlAlpha',
#     'daysForecast']},
#   'weightKey': 'PREMIUM_BRAIN_RANKING_2_DAYS',
#   'weight': 211538,
#   'created': '2020-02-06 21:38:49',
#   'lastUpdated': '2020-02-06 21:38:49'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_MERGER_ACQUISITIONS',
#   'description': 'Merger acquisition (Merger Acquisitions)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'actionType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'actionStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'acquirerCompanyId': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'acquirerSymbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'acquirerName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'targetCompanyId': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'targetSymbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'targetIsin': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'targetName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'approvalDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'closeDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'percentInterest': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'pricePerShareCurrency': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'purchasePriceCash': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'purchasePriceCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purchasePricePerShare': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'purchasePriceSharesNumber': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'etFlag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'etDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'srFlag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'srDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'secReferences': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'newsReferences': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'actionNotes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_MERGER_ACQUISITIONS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:15',
#   'lastUpdated': '2019-10-14 18:04:15'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_FORUM',
#   'description': 'Conference Events (Forum)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_FORUM',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:06',
#   'lastUpdated': '2019-10-14 18:04:06'},
#  {'id': 'NEWS',
#   'description': 'News Headlines',
#   'schema': {'type': 'object',
#    'properties': {'datetime': {'type': 'number'},
#     'headline': {'type': 'string'},
#     'source': {'type': ['string', 'null']},
#     'url': {'type': 'string'},
#     'summary': {'type': 'string'},
#     'related': {'type': 'string'}},
#    'required': ['datetime', 'headline', 'url'],
#    'additionalProperties': True},
#   'weightKey': 'NEWS',
#   'weight': 5000,
#   'created': '2019-11-07 20:28:36',
#   'lastUpdated': '2019-11-07 20:28:36'},
#  {'id': 'PREMIUM_BRAIN_RANKING_21_DAYS',
#   'description': 'The stock ranking according to Brain Machine Learning Model. Each stock is ranked by a score (or "alpha") related to the predicted future returns for the time horizon of 21 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'mlAlpha': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'daysForecast': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'compositeFigi',
#     'symbol',
#     'mlAlpha',
#     'daysForecast']},
#   'weightKey': 'PREMIUM_BRAIN_RANKING_21_DAYS',
#   'weight': 211538,
#   'created': '2020-02-26 16:43:56',
#   'lastUpdated': '2020-02-26 16:43:56'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_INITIAL_PUBLIC_OFFERING',
#   'description': 'Public Offerings (Initial public offering)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'ipoStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'modified': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'iposcoopId': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'iposcoopCompanyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'industry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fileddate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'offeringdate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'offerprice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'firstdayclose': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'currentprice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'return': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'shares': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'pricerangelow': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'pricerangehigh': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'volume': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'managers': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quietperiod': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'lockupperiod': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'rating': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_INITIAL_PUBLIC_OFFERING',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:13',
#   'lastUpdated': '2019-10-14 18:04:13'},
#  {'id': 'ECONOMIC',
#   'description': 'General economic data',
#   'schema': {'type': 'object',
#    'properties': {'value': {'type': 'number'}},
#    'required': ['value'],
#    'additionalProperties': False},
#   'weightKey': 'TIME_SERIES_ECONOMIC',
#   'weight': 1000,
#   'created': '2019-10-11 16:54:37',
#   'lastUpdated': '2019-10-11 16:54:37'},
#  {'id': 'PREMIUM_EXTRACT_ALPHA_CAM',
#   'description': 'The ExtractAlpha Cross-Asset Model 1 (CAM1) is an innovative quantitative stock selection model designed to capture the information contained in options market prices and volumes.',
#   'schema': {'type': 'object',
#    'properties': {'spreadComponent': {'type': 'number'},
#     'skewComponent': {'type': 'number'},
#     'volumeComponent': {'type': 'number'},
#     'cam1': {'type': 'number'},
#     'cam1Slow': {'type': 'number'}},
#    'required': ['spreadComponent',
#     'skewComponent',
#     'volumeComponent',
#     'cam1',
#     'cam1Slow'],
#    'additionalProperties': False},
#   'weightKey': 'PREMIUM_EXTRACT_ALPHA_CAM',
#   'weight': 76190,
#   'created': '2019-11-15 15:39:53',
#   'lastUpdated': '2019-11-15 15:39:53'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_CAPITAL_MARKETS_DAY',
#   'description': 'Analyst/Investor Events (Capital Markets day)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_CAPITAL_MARKETS_DAY',
#   'weight': 1125000,
#   'created': '2019-10-14 19:34:19',
#   'lastUpdated': '2019-10-14 19:34:19'},
#  {'id': 'PREMIUM_FRAUD_FACTORS_NON_TIMELY_FILINGS',
#   'description': 'The data set records the date in which a firm files a Non-Timely notification with the SEC.',
#   'schema': {'type': 'object',
#    'properties': {'cik': {'type': 'string'},
#     'companyName': {'type': 'string'},
#     'filingDate': {'type': 'string'},
#     'filingType': {'type': 'string'}},
#    'required': ['cik', 'filingDate', 'filingType'],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_FRAUD_FACTORS_NON_TIMELY_FILINGS',
#   'weight': 1,
#   'created': '2019-11-05 20:03:16',
#   'lastUpdated': '2019-11-05 20:03:16'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_PROJECTED_EARNINGS_ANNOUNCEMENT_DATE',
#   'description': 'Earnings Events (Projected Earnings Announcement Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'earningsDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeOfDay': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarter': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYear': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'earningsDateStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_PROJECTED_EARNINGS_ANNOUNCEMENT_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:01',
#   'lastUpdated': '2019-10-14 18:04:01'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_WORKSHOP',
#   'description': 'Conference Events (Workshop)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_WORKSHOP',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:13',
#   'lastUpdated': '2019-10-14 18:04:13'},
#  {'id': 'REPORTED_FINANCIALS',
#   'description': 'As reported financials directly from company filings. Data has not been cleaned and further manipulated. For curated financials use Cash Flow, Balance Sheet, and Income Statement endpoints.',
#   'schema': {'type': 'object',
#    'properties': {'formFiscalYear': {'type': 'number'},
#     'formFiscalQuarter': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'version': {'type': 'string'},
#     'periodStart': {'type': 'number'},
#     'periodEnd': {'type': 'number'},
#     'dateFiled': {'type': 'number'},
#     'reportLink': {'type': 'string'}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'REPORTED_FINANCIALS',
#   'weight': 5000,
#   'created': '2019-06-04 21:33:04',
#   'lastUpdated': '2019-06-04 21:33:04'},
#  {'id': 'ADVANCED_DIVIDENDS',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'adrFee': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'amount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'countryCode': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'coupon': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'declaredCurrencyCD': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'declaredDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'declaredGrossAmount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYearEndDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'frequency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fromFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'fxDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'grossAmount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'installmentPayDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'isApproximate': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'isCapitalGains': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'isDAP': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'isNetInvestmentIncome': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'marker': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'netAmount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'optionalElectionDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'periodEndDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'registrationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'secondExDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'secondPaymentDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'taxRate': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'toDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'toFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_DIVIDENDS',
#   'weight': 75000,
#   'created': '2019-11-07 13:47:37',
#   'lastUpdated': '2019-11-07 13:47:37'},
#  {'id': 'ADVANCED_SECURITY_RECLASSIFICATION',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fromFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'ratio': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'resultSecurityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'toFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_SECURITY_RECLASSIFICATION',
#   'weight': 75000,
#   'created': '2019-11-25 14:51:48',
#   'lastUpdated': '2019-11-25 14:51:48'},
#  {'id': 'FX',
#   'description': '52 pairs, SP tenor, historical forex data',
#   'schema': {'type': 'object',
#    'properties': {'timestamp': {'type': 'number'},
#     'rate': {'type': 'number'},
#     'symbol': {'type': 'string'}},
#    'required': ['timestamp', 'rate'],
#    'additionalProperties': True},
#   'weightKey': 'FX',
#   'weight': 100000,
#   'created': '2019-11-01 15:12:28',
#   'lastUpdated': '2019-11-01 15:12:28'},
#  {'id': 'ADVANCED_RIGHT_TO_PURCHASE',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'isOverSubscription': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'issuePrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
# ...
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_TRADE_SHOW',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:07',
#   'lastUpdated': '2019-10-14 18:04:07'},
#  {'id': 'PREMIUM_BRAIN_RANKING_3_DAYS',
#   'description': 'The stock ranking according to Brain Machine Learning Model. Each stock is ranked by a score (or "alpha") related to the predicted future returns for the time horizon of 3 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'mlAlpha': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'daysForecast': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'compositeFigi',
#     'symbol',
#     'mlAlpha',
#     'daysForecast']},
#   'weightKey': 'PREMIUM_BRAIN_RANKING_3_DAYS',
#   'weight': 211538,
#   'created': '2020-02-06 21:42:15',
#   'lastUpdated': '2020-02-06 21:42:15'},
#  {'id': 'PREMIUM_BRAIN_SENTIMENT_30_DAYS',
#   'description': 'Brain Company proprietary sentiment scores for each company, calculated by taking into account news articles in the past 30 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'volume': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'volumeSentiment': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'sentimentScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'numberOfDaysIncluded': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'companyName',
#     'compositeFigi',
#     'symbol',
#     'volume',
#     'volumeSentiment',
#     'sentimentScore',
#     'numberOfDaysIncluded'],
#    'additionalProperties': False},
#   'weightKey': 'PREMIUM_BRAIN_SENTIMENT_30_DAYS',
#   'weight': 60000,
#   'created': '2020-02-06 21:31:35',
#   'lastUpdated': '2020-02-06 21:31:35'},
#  {'id': 'PREMIUM_KAVOUT_KSCORE',
#   'description': 'Kavout K Score',
#   'schema': {'type': 'object',
#    'properties': {'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'tradeDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'kscore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'qualityScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'growthScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'valueScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'momentumScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['symbol', 'tradeDate'],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_KAVOUT_KSCORE',
#   'weight': 126263,
#   'created': '2020-02-26 15:59:47',
#   'lastUpdated': '2020-02-26 15:59:47'},
#  {'id': 'ENERGY',
#   'description': 'Commodities data - energy',
#   'schema': {'type': 'object',
#    'properties': {'value': {'type': 'number'}},
#    'required': ['value'],
#    'additionalProperties': False},
#   'weightKey': 'TIME_SERIES_ENERGY',
#   'weight': 1000,
#   'created': '2019-10-14 14:01:27',
#   'lastUpdated': '2019-10-14 14:01:27'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_SEMINAR',
#   'description': 'Conference Events (Seminar)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_SEMINAR',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:06',
#   'lastUpdated': '2019-10-14 18:04:06'},
#  {'id': 'PREMIUM_EXTRACT_ALPHA_TM',
#   'description': 'The ExtractAlpha Tactical Model 1 (TM1) is a quantitative stock selection model designed to capture the technical dynamics of single US equities over one to ten trading day horizons.',
#   'schema': {'type': 'object',
#    'properties': {'reversalComponent': {'type': 'number'},
#     'factorMomentumComponent': {'type': 'number'},
#     'liquidityShockComponent': {'type': 'number'},
#     'seasonalityComponent': {'type': 'number'},
#     'tm1': {'type': 'number'},
#     'listingExchange': {'type': 'string'},
#     'countryCode': {'type': 'string'}},
#    'required': ['reversalComponent',
#     'factorMomentumComponent',
#     'liquidityShockComponent',
#     'seasonalityComponent',
#     'tm1'],
#    'additionalProperties': False},
#   'weightKey': 'PREMIUM_EXTRACT_ALPHA_TM',
#   'weight': 42850,
#   'created': '2019-11-15 15:39:53',
#   'lastUpdated': '2019-11-15 15:39:53'},
#  {'id': 'ADVANCED_SPINOFF',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'effectiveDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'electionDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'hasWithdrawalRights': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'maxPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'minPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'withdrawalFromDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'withdrawalToDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_SPINOFF',
#   'weight': 75000,
#   'created': '2019-11-25 14:05:52',
#   'lastUpdated': '2019-11-25 14:05:52'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_BUSINESS_UPDATE',
#   'description': 'Analyst/Investor Events (Business Update)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_BUSINESS_UPDATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:02',
#   'lastUpdated': '2019-10-14 18:04:02'},
#  {'id': 'FX-DAILY',
#   'description': '52 pairs, SP tenor, historical forex data',
#   'schema': {'type': 'object',
#    'properties': {'timestamp': {'type': 'number'},
#     'rate': {'type': 'number'},
#     'symbol': {'type': 'string'}},
#    'required': ['timestamp', 'rate'],
#    'additionalProperties': True},
#   'weightKey': 'FX_DAILY',
#   'weight': 50000,
#   'created': '2019-10-08 17:23:18',
#   'lastUpdated': '2019-10-08 17:23:18'},
#  {'id': 'MORTGAGE',
#   'description': 'Mortgage Rates',
#   'schema': {'type': 'object',
#    'properties': {'value': {'type': 'number'}},
#    'required': ['value'],
#    'additionalProperties': False},
#   'weightKey': 'TIME_SERIES_MORTGAGE',
#   'weight': 1000,
#   'created': '2019-10-11 16:54:40',
#   'lastUpdated': '2019-10-11 16:54:40'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_COMPANY_TRAVEL',
#   'description': 'Analyst/Investor Events (Company Travel)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_COMPANY_TRAVEL',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:03',
#   'lastUpdated': '2019-10-14 18:04:03'}]

# %% [markdown]
# ####  Individual Time Series
# * Whereas calling get_time_series with no parameters returns a full inventory of time series endpoints
# * calling get_time_series with an individual series ID and (optional) keys and subkeys as parameters.
#
# * For example, to obtain the REPORTED_FINANCIALS time series entry for Apple Inc. (AAPL):

# %%
get_time_series('REPORTED_FINANCIALS', 'AAPL', token = 'pk_3e46a4b55bd04bd68bb778802602595b')

    # OR WITH A SUB KEY
# get_time_series("REPORTED_FINANCIALS", "AAPL", "10-Q")
# Out:
# [{'AccountsPayableCurrent': 46236000000,
#   'formFiscalYear': 2019,
#   'version': 'us-gaap',
#   'periodStart': 1538352000000,
#   'periodEnd': 1569801600000,
#   'dateFiled': 1572480000000,
#   'formFiscalQuarter': None,
#   'reportLink': 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019319000119/',
#   'AccountsReceivableNetCurrent': 22926000000,
#   'AccruedIncomeTaxesNoncurrent': 29545000000,
#   'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment': 58579000000,
#   'AccumulatedOtherComprehensiveIncomeLossNetOfTax': -584000000,
#   'AdjustmentsToAdditionalPaidInCapitalTaxEffectFromShareBasedCompensationIncludingTransferPricing': 620000000,
#   'AllocatedShareBasedCompensationExpense': 6068000000,
#   'AmountUtilizedUnderShareRepurchaseProgram': 96100000000,
#   'AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount': 15500000,
#   'Assets': 338516000000,
#   'AssetsCurrent': 162819000000,
#   'AssetsNoncurrent': 175697000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax': 1202000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax': 281000000,
#   'AvailableForSaleDebtSecuritiesAmortizedCostBasis': 204977000000,
#   'AvailableForSaleSecuritiesDebtSecurities': 205898000000,
#   'CashAndCashEquivalentsAtCarryingValue': 48844000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents': 50224000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect': 24311000000,
#   'CommercialPaper': 5980000000,
#   'CommitmentsAndContingencies': 0,
#   'CommonStockDividendsPerShareDeclared': 3,
#   'CommonStockParOrStatedValuePerShare': 0,
#   'CommonStockSharesAuthorized': 12600000000,
#   'CommonStockSharesIssued': 4443236000,
#   'CommonStockSharesOutstanding': 4443236000,
#   'CommonStocksIncludingAdditionalPaidInCapital': 45174000000,
#   'ComprehensiveIncomeNetOfTax': 58037000000,
#   'ContractWithCustomerLiability': 8100000000,
#   'ContractWithCustomerLiabilityCurrent': 5522000000,
#   'ContractWithCustomerLiabilityRevenueRecognized': 5900000000,
#   'CostOfGoodsAndServicesSold': 161782000000,
#   'CurrentFederalTaxExpenseBenefit': 6384000000,
#   'CurrentForeignTaxExpenseBenefit': 3962000000,
#   'CurrentStateAndLocalTaxExpenseBenefit': 475000000,
#   'DebtInstrumentCarryingAmount': 101679000000,
#   'DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet': 224000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLonger': 28167000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss': 143000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months': 28151000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss': 138000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPosition': 56318000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPositionAccumulatedLoss': 281000000,
#   'DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible': 2000000000,
#   'DeferredFederalIncomeTaxExpenseBenefit': -2939000000,
#   'DeferredForeignIncomeTaxExpenseBenefit': 2666000000,
#   'DeferredIncomeTaxExpenseBenefit': -340000000,
#   'DeferredIncomeTaxLiabilities': 11595000000,
#   'DeferredStateAndLocalIncomeTaxExpenseBenefit': -67000000,
#   'DeferredTaxAssetsDeferredIncome': 1372000000,
#   'DeferredTaxAssetsGoodwillAndIntangibleAssets': 11433000000,
#   'DeferredTaxAssetsLiabilitiesNet': 8045000000,
#   'DeferredTaxAssetsNet': 19640000000,
#   'DeferredTaxAssetsOther': 697000000,
#   'DeferredTaxAssetsPropertyPlantAndEquipment': 137000000,
#   'DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost': 749000000,
#   'DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals': 5389000000,
#   'DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross': 0,
#   'DeferredTaxLiabilitiesMinimumTaxonForeignEarnings': 10809000000,
#   'DeferredTaxLiabilitiesOther': 456000000,
#   'DeferredTaxLiabilitiesUndistributedForeignEarnings': 330000000,
#   'DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount': 19000,
#   'Depreciation': 11300000000,
#   'DepreciationDepletionAndAmortization': 12547000000,
#   'DerivativeAssetsReductionforMasterNettingArrangements': 2700000000,
#   'DerivativeFairValueOfDerivativeNet': -407000000,
#   'DerivativeLiabilitiesReductionforMasterNettingArrangements': 2700000000,
#   'EarningsPerShareBasic': 11.97,
#   'EarningsPerShareDiluted': 11.89,
#   'EffectiveIncomeTaxRateContinuingOperations': 0.159,
#   'EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate': 0.21,
#   'EffectiveIncomeTaxRateReconciliationShareBasedCompensationExcessTaxBenefitAmount': -639000000,
#   'EffectiveIncomeTaxRateReconciliationTaxCutsAndJobsActOf2017Amount': 0,
#   'EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized': 10500000000,
#   'EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense': 1967000000,
#   'EntityCommonStockSharesOutstanding': 4443265000,
#   'EntityPublicFloat': 874698000000,
#   'EquitySecuritiesWithoutReadilyDeterminableFairValueAmount': 2900000000,
#   'FederalIncomeTaxExpenseBenefitContinuingOperations': 3445000000,
#   'ForeignIncomeTaxExpenseBenefitContinuingOperations': 6628000000,
#   'GainLossFromComponentsExcludedFromAssessmentOfFairValueHedgeEffectivenessNet': 777000000,
#   'GrossProfit': 98392000000,
#   'HedgeAccountingAdjustmentsRelatedToLongTermDebt': 612000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest': 65737000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign': 44300000000,
#   'IncomeTaxesPaidNet': 15263000000,
#   'IncomeTaxExpenseBenefit': 10481000000,
#   'IncomeTaxReconciliationForeignIncomeTaxRateDifferential': -2625000000,
#   'IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate': 13805000000,
#   'IncomeTaxReconciliationOtherAdjustments': 65000000,
#   'IncomeTaxReconciliationStateAndLocalIncomeTaxes': 423000000,
#   'IncomeTaxReconciliationTaxCreditsResearch': 548000000,
#   'IncreaseDecreaseInAccountsPayable': -1923000000,
#   'IncreaseDecreaseInAccountsReceivable': -245000000,
#   'IncreaseDecreaseInContractWithCustomerLiability': -625000000,
#   'IncreaseDecreaseInInventories': 289000000,
#   'IncreaseDecreaseInOtherOperatingAssets': -873000000,
#   'IncreaseDecreaseInOtherOperatingLiabilities': -4700000000,
#   'IncreaseDecreaseInOtherReceivables': -2931000000,
#   'InterestCostsIncurred': 3200000000,
#   'InterestExpense': 3576000000,
#   'InterestPaidNet': 3423000000,
#   'InventoryNet': 4106000000,
#   'InvestmentIncomeInterestAndDividend': 4961000000,
#   'Liabilities': 248028000000,
#   'LiabilitiesAndStockholdersEquity': 338516000000,
#   'LiabilitiesCurrent': 105718000000,
#   'LiabilitiesNoncurrent': 142310000000,
#   'LongTermDebtCurrent': 10260000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive': 53802000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths': 10270000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive': 10039000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour': 9290000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree': 9528000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo': 8750000000,
#   'LongTermDebtNoncurrent': 91807000000,
#   'MarketableSecuritiesCurrent': 51713000000,
#   'MarketableSecuritiesNoncurrent': 105341000000,
#   'NetCashProvidedByUsedInFinancingActivities': -90976000000,
#   'NetCashProvidedByUsedInInvestingActivities': 45896000000,
#   'NetCashProvidedByUsedInOperatingActivities': 69391000000,
#   'NetIncomeLoss': 55256000000,
#   'NonCashActivitiesInvolvingPropertyPlantandEquipmentNetIncreaseDecreasetoAccountsPayableandOtherCurrentLiabilities': -2900000000,
#   'NoncurrentAssets': 37378000000,
#   'NonoperatingIncomeExpense': 1807000000,
#   'NontradeReceivablesCurrent': 22878000000,
#   'OperatingExpenses': 34462000000,
#   'OperatingIncomeLoss': 63930000000,
#   'OperatingLeasesFutureMinimumPaymentsDue': 10838000000,
#   'OperatingLeasesFutureMinimumPaymentsDueCurrent': 1306000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFiveYears': 834000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFourYears': 912000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInThreeYears': 1137000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInTwoYears': 1276000000,
#   'OperatingLeasesFutureMinimumPaymentsDueThereafter': 5373000000,
#   'OperatingLeasesRentExpenseNet': 1300000000,
#   'OtherAccruedLiabilitiesNoncurrent': 20958000000,
#   'OtherAssetsCurrent': 12352000000,
#   'OtherAssetsNoncurrent': 32978000000,
#   'OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax': 3827000000,
#   'OtherComprehensiveIncomeLossDerivativesQualifyingAsHedgesNetOfTax': -638000000,
#   'OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax': -408000000,
#   'OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent': 2781000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax': -25000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIOnDerivativesNetOfTax': -23000000,
#   'OtherComprehensiveIncomeUnrealizedGainLossOnDerivativesArisingDuringPeriodNetOfTax': -661000000,
#   'OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax': 3802000000,
#   'OtherLiabilitiesCurrent': 37720000000,
#   'OtherLiabilitiesNoncurrent': 50503000000,
#   'OtherNoncashIncomeExpense': 652000000,
#   'OtherNonoperatingIncomeExpense': 422000000,
#   'PaymentsForProceedsFromOtherInvestingActivities': 1078000000,
#   'PaymentsForRepurchaseOfCommonStock': 66897000000,
#   'PaymentsOfDividends': 14119000000,
#   'PaymentsRelatedToTaxWithholdingForShareBasedCompensation': 2817000000,
#   'PaymentsToAcquireAvailableForSaleSecuritiesDebt': 39630000000,
#   'PaymentsToAcquireBusinessesNetOfCashAcquired': 624000000,
#   'PaymentsToAcquireOtherInvestments': 1001000000,
#   'PaymentsToAcquirePropertyPlantAndEquipment': 10495000000,
#   'PerformanceObligationsinArrangements': 3,
#   'ProceedsFromIssuanceOfCommonStock': 781000000,
#   'ProceedsFromIssuanceOfLongTermDebt': 6963000000,
#   'ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities': 40102000000,
#   'ProceedsFromPaymentsForOtherFinancingActivities': -105000000,
#   'ProceedsFromRepaymentsOfCommercialPaper': -5977000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': -2729000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess': -3248000000,
#   'ProceedsFromSaleAndMaturityOfOtherInvestments': 1634000000,
#   'ProceedsFromSaleOfAvailableForSaleSecuritiesDebt': 56988000000,
#   'ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths': 13874000000,
#   'PropertyPlantAndEquipmentGross': 95957000000,
#   'PropertyPlantAndEquipmentNet': 37378000000,
#   'RepaymentsOfLongTermDebt': 8805000000,
#   'RepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': 16603000000,
#   'ResearchAndDevelopmentExpense': 16217000000,
#   'RestrictedCashAndCashEquivalentsAtCarryingValue': 23000000,
#   'RestrictedCashAndCashEquivalentsNoncurrent': 1357000000,
#   'RestrictedInvestments': 18900000000,
#   'RetainedEarningsAccumulatedDeficit': 45898000000,
#   'RevenueFromContractWithCustomerExcludingAssessedTax': 260174000000,
#   'SellingGeneralAndAdministrativeExpense': 18245000000,
#   'ShareBasedCompensation': 6068000000,
#   'ShortTermDebtWeightedAverageInterestRate': 0.0224,
#   'StandardProductWarrantyAccrual': 3570000000,
#   'StandardProductWarrantyAccrualPayments': 3857000000,
#   'StandardProductWarrantyAccrualWarrantiesIssued': 3735000000,
#   'StateAndLocalIncomeTaxExpenseBenefitContinuingOperations': 408000000,
#   'StockholdersEquity': 90488000000,
#   'StockRepurchasedAndRetiredDuringPeriodShares': 345200000,
#   'StockRepurchasedAndRetiredDuringPeriodValue': 67100000000,
#   'StockRepurchaseProgramAuthorizedAmount1': 175000000000,
#   'UnrecognizedTaxBenefits': 15619000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions': 686000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities': 852000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued': 1300000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestExpense': 73000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions': 1697000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions': 5845000000,
#   'UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations': 79000000,
#   'UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate': 8600000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary': 218000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary': 2476000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary': 1162000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary': 2386000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary': 1859000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount': 8211000000,
#   'UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears': 110000000,
#   'WeightedAverageNumberDilutedSharesOutstandingAdjustment': 31079000,
#   'WeightedAverageNumberOfDilutedSharesOutstanding': 4648913000,
#   'WeightedAverageNumberOfSharesOutstandingBasic': 4617834000,
#   'id': 'REPORTED_FINANCIALS',
#   'source': 'SEC',
#   'key': 'AAPL',
#   'subkey': '10-K',
#   'date': 1572480000000,
#   'updated': 1581627630000}]

# %%
get_time_series("REPORTED_FINANCIALS", "AAPL", "10-K", last=1, token = 'pk_3e46a4b55bd04bd68bb778802602595b')
# Out:
# [{'AccountsPayableCurrent': 46236000000,
#   'formFiscalYear': 2019,
#   'version': 'us-gaap',
#   'periodStart': 1538352000000,
#   'periodEnd': 1569801600000,
#   'dateFiled': 1572480000000,
#   'formFiscalQuarter': None,
#   'reportLink': 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019319000119/',
#   'AccountsReceivableNetCurrent': 22926000000,
#   'AccruedIncomeTaxesNoncurrent': 29545000000,
#   'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment': 58579000000,
#   'AccumulatedOtherComprehensiveIncomeLossNetOfTax': -584000000,
#   'AdjustmentsToAdditionalPaidInCapitalTaxEffectFromShareBasedCompensationIncludingTransferPricing': 620000000,
#   'AllocatedShareBasedCompensationExpense': 6068000000,
#   'AmountUtilizedUnderShareRepurchaseProgram': 96100000000,
#   'AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount': 15500000,
#   'Assets': 338516000000,
#   'AssetsCurrent': 162819000000,
#   'AssetsNoncurrent': 175697000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax': 1202000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax': 281000000,
#   'AvailableForSaleDebtSecuritiesAmortizedCostBasis': 204977000000,
#   'AvailableForSaleSecuritiesDebtSecurities': 205898000000,
#   'CashAndCashEquivalentsAtCarryingValue': 48844000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents': 50224000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect': 24311000000,
#   'CommercialPaper': 5980000000,
#   'CommitmentsAndContingencies': 0,
#   'CommonStockDividendsPerShareDeclared': 3,
#   'CommonStockParOrStatedValuePerShare': 0,
#   'CommonStockSharesAuthorized': 12600000000,
#   'CommonStockSharesIssued': 4443236000,
#   'CommonStockSharesOutstanding': 4443236000,
#   'CommonStocksIncludingAdditionalPaidInCapital': 45174000000,
#   'ComprehensiveIncomeNetOfTax': 58037000000,
#   'ContractWithCustomerLiability': 8100000000,
#   'ContractWithCustomerLiabilityCurrent': 5522000000,
#   'ContractWithCustomerLiabilityRevenueRecognized': 5900000000,
#   'CostOfGoodsAndServicesSold': 161782000000,
#   'CurrentFederalTaxExpenseBenefit': 6384000000,
#   'CurrentForeignTaxExpenseBenefit': 3962000000,
#   'CurrentStateAndLocalTaxExpenseBenefit': 475000000,
#   'DebtInstrumentCarryingAmount': 101679000000,
#   'DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet': 224000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLonger': 28167000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss': 143000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months': 28151000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss': 138000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPosition': 56318000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPositionAccumulatedLoss': 281000000,
#   'DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible': 2000000000,
#   'DeferredFederalIncomeTaxExpenseBenefit': -2939000000,
#   'DeferredForeignIncomeTaxExpenseBenefit': 2666000000,
#   'DeferredIncomeTaxExpenseBenefit': -340000000,
#   'DeferredIncomeTaxLiabilities': 11595000000,
#   'DeferredStateAndLocalIncomeTaxExpenseBenefit': -67000000,
#   'DeferredTaxAssetsDeferredIncome': 1372000000,
#   'DeferredTaxAssetsGoodwillAndIntangibleAssets': 11433000000,
#   'DeferredTaxAssetsLiabilitiesNet': 8045000000,
#   'DeferredTaxAssetsNet': 19640000000,
#   'DeferredTaxAssetsOther': 697000000,
#   'DeferredTaxAssetsPropertyPlantAndEquipment': 137000000,
#   'DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost': 749000000,
#   'DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals': 5389000000,
#   'DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross': 0,
#   'DeferredTaxLiabilitiesMinimumTaxonForeignEarnings': 10809000000,
#   'DeferredTaxLiabilitiesOther': 456000000,
#   'DeferredTaxLiabilitiesUndistributedForeignEarnings': 330000000,
#   'DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount': 19000,
#   'Depreciation': 11300000000,
#   'DepreciationDepletionAndAmortization': 12547000000,
#   'DerivativeAssetsReductionforMasterNettingArrangements': 2700000000,
#   'DerivativeFairValueOfDerivativeNet': -407000000,
#   'DerivativeLiabilitiesReductionforMasterNettingArrangements': 2700000000,
#   'EarningsPerShareBasic': 11.97,
#   'EarningsPerShareDiluted': 11.89,
#   'EffectiveIncomeTaxRateContinuingOperations': 0.159,
#   'EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate': 0.21,
#   'EffectiveIncomeTaxRateReconciliationShareBasedCompensationExcessTaxBenefitAmount': -639000000,
#   'EffectiveIncomeTaxRateReconciliationTaxCutsAndJobsActOf2017Amount': 0,
#   'EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized': 10500000000,
#   'EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense': 1967000000,
#   'EntityCommonStockSharesOutstanding': 4443265000,
#   'EntityPublicFloat': 874698000000,
#   'EquitySecuritiesWithoutReadilyDeterminableFairValueAmount': 2900000000,
#   'FederalIncomeTaxExpenseBenefitContinuingOperations': 3445000000,
#   'ForeignIncomeTaxExpenseBenefitContinuingOperations': 6628000000,
#   'GainLossFromComponentsExcludedFromAssessmentOfFairValueHedgeEffectivenessNet': 777000000,
#   'GrossProfit': 98392000000,
#   'HedgeAccountingAdjustmentsRelatedToLongTermDebt': 612000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest': 65737000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign': 44300000000,
#   'IncomeTaxesPaidNet': 15263000000,
#   'IncomeTaxExpenseBenefit': 10481000000,
#   'IncomeTaxReconciliationForeignIncomeTaxRateDifferential': -2625000000,
#   'IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate': 13805000000,
#   'IncomeTaxReconciliationOtherAdjustments': 65000000,
#   'IncomeTaxReconciliationStateAndLocalIncomeTaxes': 423000000,
#   'IncomeTaxReconciliationTaxCreditsResearch': 548000000,
#   'IncreaseDecreaseInAccountsPayable': -1923000000,
#   'IncreaseDecreaseInAccountsReceivable': -245000000,
#   'IncreaseDecreaseInContractWithCustomerLiability': -625000000,
#   'IncreaseDecreaseInInventories': 289000000,
#   'IncreaseDecreaseInOtherOperatingAssets': -873000000,
#   'IncreaseDecreaseInOtherOperatingLiabilities': -4700000000,
#   'IncreaseDecreaseInOtherReceivables': -2931000000,
#   'InterestCostsIncurred': 3200000000,
#   'InterestExpense': 3576000000,
#   'InterestPaidNet': 3423000000,
#   'InventoryNet': 4106000000,
#   'InvestmentIncomeInterestAndDividend': 4961000000,
#   'Liabilities': 248028000000,
#   'LiabilitiesAndStockholdersEquity': 338516000000,
#   'LiabilitiesCurrent': 105718000000,
#   'LiabilitiesNoncurrent': 142310000000,
#   'LongTermDebtCurrent': 10260000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive': 53802000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths': 10270000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive': 10039000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour': 9290000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree': 9528000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo': 8750000000,
#   'LongTermDebtNoncurrent': 91807000000,
#   'MarketableSecuritiesCurrent': 51713000000,
#   'MarketableSecuritiesNoncurrent': 105341000000,
#   'NetCashProvidedByUsedInFinancingActivities': -90976000000,
#   'NetCashProvidedByUsedInInvestingActivities': 45896000000,
#   'NetCashProvidedByUsedInOperatingActivities': 69391000000,
#   'NetIncomeLoss': 55256000000,
#   'NonCashActivitiesInvolvingPropertyPlantandEquipmentNetIncreaseDecreasetoAccountsPayableandOtherCurrentLiabilities': -2900000000,
#   'NoncurrentAssets': 37378000000,
#   'NonoperatingIncomeExpense': 1807000000,
#   'NontradeReceivablesCurrent': 22878000000,
#   'OperatingExpenses': 34462000000,
#   'OperatingIncomeLoss': 63930000000,
#   'OperatingLeasesFutureMinimumPaymentsDue': 10838000000,
#   'OperatingLeasesFutureMinimumPaymentsDueCurrent': 1306000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFiveYears': 834000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFourYears': 912000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInThreeYears': 1137000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInTwoYears': 1276000000,
#   'OperatingLeasesFutureMinimumPaymentsDueThereafter': 5373000000,
#   'OperatingLeasesRentExpenseNet': 1300000000,
#   'OtherAccruedLiabilitiesNoncurrent': 20958000000,
#   'OtherAssetsCurrent': 12352000000,
#   'OtherAssetsNoncurrent': 32978000000,
#   'OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax': 3827000000,
#   'OtherComprehensiveIncomeLossDerivativesQualifyingAsHedgesNetOfTax': -638000000,
#   'OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax': -408000000,
#   'OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent': 2781000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax': -25000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIOnDerivativesNetOfTax': -23000000,
#   'OtherComprehensiveIncomeUnrealizedGainLossOnDerivativesArisingDuringPeriodNetOfTax': -661000000,
#   'OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax': 3802000000,
#   'OtherLiabilitiesCurrent': 37720000000,
#   'OtherLiabilitiesNoncurrent': 50503000000,
#   'OtherNoncashIncomeExpense': 652000000,
#   'OtherNonoperatingIncomeExpense': 422000000,
#   'PaymentsForProceedsFromOtherInvestingActivities': 1078000000,
#   'PaymentsForRepurchaseOfCommonStock': 66897000000,
#   'PaymentsOfDividends': 14119000000,
#   'PaymentsRelatedToTaxWithholdingForShareBasedCompensation': 2817000000,
#   'PaymentsToAcquireAvailableForSaleSecuritiesDebt': 39630000000,
#   'PaymentsToAcquireBusinessesNetOfCashAcquired': 624000000,
#   'PaymentsToAcquireOtherInvestments': 1001000000,
#   'PaymentsToAcquirePropertyPlantAndEquipment': 10495000000,
#   'PerformanceObligationsinArrangements': 3,
#   'ProceedsFromIssuanceOfCommonStock': 781000000,
#   'ProceedsFromIssuanceOfLongTermDebt': 6963000000,
#   'ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities': 40102000000,
#   'ProceedsFromPaymentsForOtherFinancingActivities': -105000000,
#   'ProceedsFromRepaymentsOfCommercialPaper': -5977000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': -2729000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess': -3248000000,
#   'ProceedsFromSaleAndMaturityOfOtherInvestments': 1634000000,
#   'ProceedsFromSaleOfAvailableForSaleSecuritiesDebt': 56988000000,
#   'ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths': 13874000000,
#   'PropertyPlantAndEquipmentGross': 95957000000,
#   'PropertyPlantAndEquipmentNet': 37378000000,
#   'RepaymentsOfLongTermDebt': 8805000000,
#   'RepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': 16603000000,
#   'ResearchAndDevelopmentExpense': 16217000000,
#   'RestrictedCashAndCashEquivalentsAtCarryingValue': 23000000,
#   'RestrictedCashAndCashEquivalentsNoncurrent': 1357000000,
#   'RestrictedInvestments': 18900000000,
#   'RetainedEarningsAccumulatedDeficit': 45898000000,
#   'RevenueFromContractWithCustomerExcludingAssessedTax': 260174000000,
#   'SellingGeneralAndAdministrativeExpense': 18245000000,
#   'ShareBasedCompensation': 6068000000,
#   'ShortTermDebtWeightedAverageInterestRate': 0.0224,
#   'StandardProductWarrantyAccrual': 3570000000,
#   'StandardProductWarrantyAccrualPayments': 3857000000,
#   'StandardProductWarrantyAccrualWarrantiesIssued': 3735000000,
#   'StateAndLocalIncomeTaxExpenseBenefitContinuingOperations': 408000000,
#   'StockholdersEquity': 90488000000,
#   'StockRepurchasedAndRetiredDuringPeriodShares': 345200000,
#   'StockRepurchasedAndRetiredDuringPeriodValue': 67100000000,
#   'StockRepurchaseProgramAuthorizedAmount1': 175000000000,
#   'UnrecognizedTaxBenefits': 15619000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions': 686000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities': 852000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued': 1300000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestExpense': 73000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions': 1697000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions': 5845000000,
#   'UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations': 79000000,
#   'UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate': 8600000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary': 218000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary': 2476000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary': 1162000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary': 2386000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary': 1859000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount': 8211000000,
#   'UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears': 110000000,
#   'WeightedAverageNumberDilutedSharesOutstandingAdjustment': 31079000,
#   'WeightedAverageNumberOfDilutedSharesOutstanding': 4648913000,
#   'WeightedAverageNumberOfSharesOutstandingBasic': 4617834000,
#   'id': 'REPORTED_FINANCIALS',
#   'source': 'SEC',
#   'key': 'AAPL',
#   'subkey': '10-K',
#   'date': 1572480000000,
#   'updated': 1581627630000}]

# %% [markdown]
# ### Historical Data
# * It's possible to obtain historical data using get_historical_data and get_historical_intraday.

# %% [markdown]
# #### Daily
# * To obtain daily historical price data for one or more symbols, use the get_historical_data function.
# * This will return a daily time-series of the ticker requested over the desired date range
#     * (start and end passed as datetime.datetime objects):

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_data

start = datetime(2017, 1, 1)
end = datetime(2018, 1, 1)

df = get_historical_data("TSLA", start, end, token='pk_b740ad24ded147cca822e98ded174c3d')
df
# Out:
# {'2017-01-03': {'open': 214.86,
#   'high': 220.33,
#   'low': 210.96,
#   'close': 216.99,
#   'volume': 5923254},
#  '2017-01-04': {'open': 214.75,
#   'high': 228.0,
#   'low': 214.31,
#   'close': 226.99,
#   'volume': 11213471},
#  '2017-01-05': {'open': 226.42,
#   'high': 227.48,
#   'low': 221.95,
#   'close': 226.75,
#   'volume': 5911695},
#  '2017-01-06': {'open': 226.93,
#   'high': 230.31,
#   'low': 225.45,
#   'close': 229.01,
#   'volume': 5527893},
#  '2017-01-09': {'open': 228.97,
#   'high': 231.92,
#   'low': 228.0,
#   'close': 231.28,
#   'volume': 3979484},
#  '2017-01-10': {'open': 232.0,
#   'high': 232.0,
#   'low': 226.89,
#   'close': 229.87,
#   'volume': 3659955},
#  '2017-01-11': {'open': 229.07,
#   'high': 229.98,
#   'low': 226.68,
#   'close': 229.73,
#   'volume': 3650825},
#  '2017-01-12': {'open': 229.06,
#   'high': 230.7,
#   'low': 225.58,
#   'close': 229.59,
#   'volume': 3790229},
#  '2017-01-13': {'open': 230.0,
#   'high': 237.85,
#   'low': 229.59,
#   'close': 237.75,
#   'volume': 6092960},
#  '2017-01-17': {'open': 236.7,
#   'high': 239.96,
#   'low': 234.37,
#   'close': 235.58,
#   'volume': 4617522},
#  '2017-01-18': {'open': 236.65,
#   'high': 239.71,
#   'low': 235.58,
#   'close': 238.36,
#   'volume': 3768967},
#  '2017-01-19': {'open': 247.25,
#   'high': 248.68,
#   'low': 240.75,
#   'close': 243.76,
#   'volume': 7732303},
#  '2017-01-20': {'open': 245.46,
#   'high': 246.0,
#   'low': 243.01,
#   'close': 244.73,
#   'volume': 4204275},
#  '2017-01-23': {'open': 245.85,
#   'high': 250.89,
#   'low': 245.5,
#   'close': 248.92,
#   'volume': 6262938},
#  '2017-01-24': {'open': 250.0,
#   'high': 254.8,
#   'low': 249.65,
#   'close': 254.61,
#   'volume': 4965451},
#  '2017-01-25': {'open': 257.31,
#   'high': 258.46,
#   'low': 251.8,
#   'close': 254.47,
#   'volume': 5146361},
#  '2017-01-26': {'open': 254.29,
#   'high': 255.74,
#   'low': 250.75,
#   'close': 252.51,
#   'volume': 3152123},
#  '2017-01-27': {'open': 251.38,
#   'high': 253.0,
#   'low': 248.52,
#   'close': 252.95,
#   'volume': 3166336},
#  '2017-01-30': {'open': 252.53,
#   'high': 255.29,
#   'low': 247.1,
#   'close': 250.63,
#   'volume': 3801074},
#  '2017-01-31': {'open': 249.24,
#   'high': 255.89,
#   'low': 247.7,
#   'close': 251.93,
#   'volume': 4116104},
#  '2017-02-01': {'open': 253.05,
#   'high': 253.2,
#   'low': 249.05,
#   'close': 249.24,
#   'volume': 3958829},
#  '2017-02-02': {'open': 248.34,
#   'high': 252.42,
#   'low': 247.71,
#   'close': 251.55,
#   'volume': 2499775},
#  '2017-02-03': {'open': 251.91,
#   'high': 252.18,
#   'low': 249.68,
#   'close': 251.33,
#   'volume': 2186723},
#  '2017-02-06': {'open': 251.0,
#   'high': 257.82,
#   'low': 250.63,
#   'close': 257.77,
#   'volume': 3562517},
#  '2017-02-07': {'open': 258.19,
#   'high': 260.0,
#   'low': 256.42,
#   'close': 257.48,
#   'volume': 4244775},
#  '2017-02-08': {'open': 257.35,
#   'high': 263.36,
#   'low': 256.2,
#   'close': 262.08,
#   'volume': 3933014},
#  '2017-02-09': {'open': 266.25,
#   'high': 271.18,
#   'low': 266.15,
#   'close': 269.2,
#   'volume': 7820222},
#  '2017-02-10': {'open': 269.79,
#   'high': 270.95,
#   'low': 266.11,
#   'close': 269.23,
#   'volume': 3619739},
#  '2017-02-13': {'open': 270.74,
#   'high': 280.79,
#   'low': 270.51,
#   'close': 280.6,
#   'volume': 7029605},
#  '2017-02-14': {'open': 279.03,
#   'high': 287.39,
#   'low': 278.61,
#   'close': 280.98,
#   'volume': 7345224},
#  '2017-02-15': {'open': 280.0,
#   'high': 282.24,
#   'low': 276.44,
#   'close': 279.76,
#   'volume': 4947856},
#  '2017-02-16': {'open': 277.6,
#   'high': 280.0,
#   'low': 268.5,
#   'close': 268.95,
#   'volume': 7077322},
#  '2017-02-17': {'open': 265.8,
#   'high': 272.89,
#   'low': 264.15,
#   'close': 272.23,
#   'volume': 6257149},
#  '2017-02-21': {'open': 275.45,
#   'high': 281.4,
#   'low': 274.01,
#   'close': 277.39,
#   'volume': 5676747},
#  '2017-02-22': {'open': 280.31,
#   'high': 283.45,
#   'low': 272.6,
#   'close': 273.51,
#   'volume': 8754975},
#  '2017-02-23': {'open': 264.0,
#   'high': 264.66,
#   'low': 255.56,
#   'close': 255.99,
#   'volume': 14915249},
#  '2017-02-24': {'open': 252.66,
#   'high': 258.25,
#   'low': 250.2,
#   'close': 257.0,
#   'volume': 8171626},
#  '2017-02-27': {'open': 248.17,
#   'high': 248.36,
#   'low': 242.01,
#   'close': 246.23,
#   'volume': 11460810},
#  '2017-02-28': {'open': 244.19,
#   'high': 251.0,
#   'low': 243.9,
#   'close': 249.99,
#   'volume': 6078145},
#  '2017-03-01': {'open': 254.18,
#   'high': 254.85,
#   'low': 249.11,
#   'close': 250.02,
#   'volume': 4809488},
#  '2017-03-02': {'open': 249.71,
#   'high': 253.28,
#   'low': 248.27,
#   'close': 250.48,
#   'volume': 3351833},
#  '2017-03-03': {'open': 250.74,
#   'high': 251.9,
#   'low': 249.0,
#   'close': 251.57,
#   'volume': 2929234},
#  '2017-03-06': {'open': 247.91,
#   'high': 251.7,
#   'low': 247.51,
#   'close': 251.21,
#   'volume': 3355500},
#  '2017-03-07': {'open': 251.92,
#   'high': 253.89,
#   'low': 248.32,
#   'close': 248.59,
#   'volume': 3459470},
#  '2017-03-08': {'open': 247.0,
#   'high': 250.07,
#   'low': 245.32,
#   'close': 246.87,
#   'volume': 3728649},
#  '2017-03-09': {'open': 247.63,
#   'high': 248.66,
#   'low': 243.0,
#   'close': 244.9,
#   'volume': 3879293},
#  '2017-03-10': {'open': 246.21,
#   'high': 246.5,
#   'low': 243.0,
#   'close': 243.69,
#   'volume': 3066272},
#  '2017-03-13': {'open': 244.82,
#   'high': 246.85,
#   'low': 242.78,
#   'close': 246.17,
#   'volume': 3022625},
#  '2017-03-14': {'open': 246.11,
#   'high': 258.12,
#   'low': 246.02,
#   'close': 258.0,
#   'volume': 7598446},
#  '2017-03-15': {'open': 257.0,
#   'high': 261.0,
#   'low': 254.27,
#   'close': 255.73,
#   'volume': 5330806},
#  '2017-03-16': {'open': 262.4,
#   'high': 265.75,
#   'low': 259.06,
#   'close': 262.05,
#   'volume': 7132153},
#  '2017-03-17': {'open': 264.0,
#   'high': 265.33,
#   'low': 261.2,
#   'close': 261.5,
#   'volume': 6497496},
#  '2017-03-20': {'open': 260.6,
#   'high': 264.55,
#   'low': 258.82,
#   'close': 261.92,
#   'volume': 3614294},
#  '2017-03-21': {'open': 262.83,
#   'high': 264.8,
#   'low': 250.24,
#   'close': 250.68,
#   'volume': 6908554},
#  '2017-03-22': {'open': 251.56,
#   'high': 255.07,
#   'low': 250.51,
#   'close': 255.01,
#   'volume': 4059297},
#  '2017-03-23': {'open': 255.39,
#   'high': 257.67,
#   'low': 253.3,
#   'close': 254.78,
#   'volume': 3320245},
#  '2017-03-24': {'open': 255.7,
#   'high': 263.89,
#   'low': 255.01,
#   'close': 263.16,
#   'volume': 5647253},
#  '2017-03-27': {'open': 260.6,
#   'high': 270.57,
#   'low': 259.75,
#   'close': 270.22,
#   'volume': 6230795},
#  '2017-03-28': {'open': 277.02,
#   'high': 280.68,
#   'low': 275.0,
#   'close': 277.45,
#   'volume': 7987604},
#  '2017-03-29': {'open': 278.34,
#   'high': 279.6,
#   'low': 275.54,
#   'close': 277.38,
#   'volume': 3676157},
#  '2017-03-30': {'open': 278.04,
#   'high': 282.0,
#   'low': 277.21,
#   'close': 277.92,
#   'volume': 4148426},
#  '2017-03-31': {'open': 278.73,
#   'high': 279.68,
#   'low': 276.32,
#   'close': 278.3,
#   'volume': 3294640},
#  '2017-04-03': {'open': 286.9,
#   'high': 299.0,
#   'low': 284.58,
#   'close': 298.52,
#   'volume': 13888618},
#  '2017-04-04': {'open': 296.89,
#   'high': 304.81,
#   'low': 294.53,
#   'close': 303.7,
#   'volume': 10134556},
#  '2017-04-05': {'open': 302.04,
#   'high': 304.88,
#   'low': 294.2,
#   'close': 295.0,
#   'volume': 7880938},
#  '2017-04-06': {'open': 296.88,
#   'high': 301.94,
#   'low': 294.1,
#   'close': 298.7,
#   'volume': 5520588},
#  '2017-04-07': {'open': 297.5,
#   'high': 302.69,
#   'low': 297.15,
#   'close': 302.54,
#   'volume': 4579613},
#  '2017-04-10': {'open': 309.15,
#   'high': 313.73,
#   'low': 308.71,
#   'close': 312.39,
#   'volume': 7664458},
#  '2017-04-11': {'open': 313.38,
#   'high': 313.47,
#   'low': 305.5,
#   'close': 308.71,
#   'volume': 5724577},
#  '2017-04-12': {'open': 306.34,
#   'high': 308.45,
#   'low': 296.32,
#   'close': 296.84,
#   'volume': 6050682},
#  '2017-04-13': {'open': 296.7,
#   'high': 307.39,
#   'low': 295.3,
#   'close': 304.0,
#   'volume': 9284634},
#  '2017-04-17': {'open': 302.7,
#   'high': 304.0,
#   'low': 298.68,
#   'close': 301.44,
#   'volume': 4138736},
#  '2017-04-18': {'open': 299.7,
#   'high': 300.84,
#   'low': 297.9,
#   'close': 300.25,
#   'volume': 3035698},
#  '2017-04-19': {'open': 302.46,
#   'high': 306.62,
#   'low': 302.11,
#   'close': 305.52,
#   'volume': 3898024},
#  '2017-04-20': {'open': 306.51,
#   'high': 309.15,
#   'low': 300.23,
#   'close': 302.51,
#   'volume': 6149352},
#  '2017-04-21': {'open': 302.0,
#   'high': 306.4,
#   'low': 300.42,
#   'close': 305.6,
#   'volume': 4509756},
#  '2017-04-24': {'open': 309.22,
#   'high': 310.55,
#   'low': 306.02,
#   'close': 308.03,
#   'volume': 5083505},
#  '2017-04-25': {'open': 308.0,
#   'high': 313.98,
#   'low': 305.86,
#   'close': 313.79,
#   'volume': 6737708},
#  '2017-04-26': {'open': 312.37,
#   'high': 314.5,
#   'low': 309.0,
#   'close': 310.17,
#   'volume': 4695044},
#  '2017-04-27': {'open': 311.69,
#   'high': 313.09,
#   'low': 307.5,
#   'close': 308.63,
#   'volume': 3468569},
#  '2017-04-28': {'open': 309.83,
#   'high': 314.8,
#   'low': 308.0,
#   'close': 314.07,
#   'volume': 4505478},
#  '2017-05-01': {'open': 314.88,
#   'high': 327.25,
#   'low': 314.81,
#   'close': 322.83,
#   'volume': 8829565},
#  '2017-05-02': {'open': 324.0,
#   'high': 327.66,
#   'low': 316.56,
#   'close': 318.89,
#   'volume': 5382777},
#  '2017-05-03': {'open': 317.67,
#   'high': 321.53,
#   'low': 310.45,
#   'close': 311.02,
#   'volume': 7133365},
#  '2017-05-04': {'open': 307.44,
#   'high': 307.77,
#   'low': 290.76,
#   'close': 295.46,
#   'volume': 14152008},
#  '2017-05-05': {'open': 298.0,
#   'high': 308.55,
#   'low': 296.8,
#   'close': 308.35,
#   'volume': 8177347},
#  '2017-05-08': {'open': 310.9,
#   'high': 313.79,
#   'low': 305.82,
#   'close': 307.19,
#   'volume': 7006471},
#  '2017-05-09': {'open': 309.38,
#   'high': 321.99,
#   'low': 309.1,
#   'close': 321.26,
#   'volume': 9676537},
#  '2017-05-10': {'open': 321.56,
#   'high': 325.5,
#   'low': 318.12,
#   'close': 325.22,
#   'volume': 5741607},
#  '2017-05-11': {'open': 323.4,
#   'high': 326.0,
#   'low': 319.6,
#   'close': 323.1,
#   'volume': 4753819},
#  '2017-05-12': {'open': 325.48,
#   'high': 327.0,
#   'low': 321.53,
#   'close': 324.81,
#   'volume': 4121612},
#  '2017-05-15': {'open': 318.38,
#   'high': 320.2,
#   'low': 312.53,
#   'close': 315.88,
#   'volume': 7622004},
#  '2017-05-16': {'open': 317.59,
#   'high': 320.06,
#   'low': 315.14,
#   'close': 317.01,
#   'volume': 4152484},
#  '2017-05-17': {'open': 314.39,
#   'high': 314.63,
#   'low': 305.5,
#   'close': 306.11,
#   'volume': 6711940},
#  '2017-05-18': {'open': 307.0,
#   'high': 313.94,
#   'low': 305.31,
#   'close': 313.06,
#   'volume': 5653801},
#  '2017-05-19': {'open': 315.5,
#   'high': 316.5,
#   'low': 310.2,
#   'close': 310.83,
#   'volume': 4687572},
#  '2017-05-22': {'open': 312.8,
#   'high': 314.37,
#   'low': 306.8,
#   'close': 310.35,
#   'volume': 4329178},
#  '2017-05-23': {'open': 310.46,
#   'high': 310.73,
#   'low': 303.48,
#   'close': 303.86,
#   'volume': 4318354},
#  '2017-05-24': {'open': 306.51,
#   'high': 311.0,
#   'low': 305.4,
#   'close': 310.22,
#   'volume': 5041692},
#  '2017-05-25': {'open': 311.02,
#   'high': 316.97,
#   'low': 307.81,
#   'close': 316.83,
#   'volume': 5013963},
#  '2017-05-26': {'open': 317.28,
#   'high': 325.49,
#   'low': 316.31,
#   'close': 325.14,
#   'volume': 7802199},
#  '2017-05-30': {'open': 326.0,
#   'high': 336.28,
#   'low': 325.76,
#   'close': 335.1,
#   'volume': 7782916},
#  '2017-05-31': {'open': 337.69,
#   'high': 342.89,
#   'low': 335.16,
#   'close': 341.01,
#   'volume': 9963444},
#  '2017-06-01': {'open': 344.0,
#   'high': 344.88,
#   'low': 337.29,
#   'close': 340.37,
#   'volume': 7607996},
#  '2017-06-02': {'open': 339.77,
#   'high': 342.88,
#   'low': 335.93,
#   'close': 339.85,
#   'volume': 5590239},
#  '2017-06-05': {'open': 338.5,
#   'high': 348.44,
#   'low': 334.21,
#   'close': 347.32,
#   'volume': 6784368},
#  '2017-06-06': {'open': 344.7,
#   'high': 359.49,
#   'low': 339.97,
#   'close': 352.85,
#   'volume': 11086798},
#  '2017-06-07': {'open': 356.34,
#   'high': 360.5,
#   'low': 355.14,
#   'close': 359.65,
#   'volume': 9397959},
#  '2017-06-08': {'open': 363.75,
#   'high': 371.9,
#   'low': 360.22,
#   'close': 370.0,
#   'volume': 9061496},
#  '2017-06-09': {'open': 374.42,
#   'high': 376.87,
#   'low': 354.8,
#   'close': 357.32,
#   'volume': 17261435},
#  '2017-06-12': {'open': 357.99,
#   'high': 364.5,
#   'low': 350.62,
#   'close': 359.01,
#   'volume': 10517660},
#  '2017-06-13': {'open': 367.62,
#   'high': 376.0,
#   'low': 366.61,
#   'close': 375.95,
#   'volume': 11807920},
#  '2017-06-14': {'open': 381.09,
#   'high': 384.25,
#   'low': 376.31,
#   'close': 380.66,
#   'volume': 12818429},
#  '2017-06-15': {'open': 372.5,
#   'high': 375.46,
#   'low': 366.49,
#   'close': 375.34,
#   'volume': 10426469},
#  '2017-06-16': {'open': 377.98,
#   'high': 378.01,
#   'low': 370.1,
#   'close': 371.4,
#   'volume': 6730973},
#  '2017-06-19': {'open': 375.0,
#   'high': 376.7,
#   'low': 367.8,
#   'close': 369.8,
#   'volume': 6549332},
#  '2017-06-20': {'open': 376.67,
#   'high': 378.88,
#   'low': 369.73,
#   'close': 372.24,
#   'volume': 7438701},
#  '2017-06-21': {'open': 374.35,
#   'high': 376.99,
#   'low': 368.02,
#   'close': 376.4,
#   'volume': 4923210},
#  '2017-06-22': {'open': 377.99,
#   'high': 385.0,
#   'low': 373.57,
#   'close': 382.61,
#   'volume': 7529778},
#  '2017-06-23': {'open': 382.45,
#   'high': 386.99,
#   'low': 379.35,
#   'close': 383.45,
#   'volume': 6445758},
#  '2017-06-26': {'open': 386.69,
#   'high': 386.95,
#   'low': 373.1,
#   'close': 377.49,
#   'volume': 6604099},
#  '2017-06-27': {'open': 376.4,
#   'high': 376.4,
#   'low': 362.02,
#   'close': 362.37,
#   'volume': 6996399},
#  '2017-06-28': {'open': 366.68,
#   'high': 371.74,
#   'low': 362.52,
#   'close': 371.24,
#   'volume': 6302463},
#  '2017-06-29': {'open': 370.61,
#   'high': 371.0,
#   'low': 354.1,
#   'close': 360.75,
#   'volume': 8221038},
#  '2017-06-30': {'open': 363.71,
#   'high': 366.77,
#   'low': 359.62,
#   'close': 361.61,
#   'volume': 5848521},
#  '2017-07-03': {'open': 370.24,
#   'high': 371.35,
#   'low': 351.5,
#   'close': 352.62,
#   'volume': 6305401},
#  '2017-07-05': {'open': 347.2,
#   'high': 347.24,
#   'low': 326.33,
#   'close': 327.09,
#   'volume': 17046701},
#  '2017-07-06': {'open': 317.26,
#   'high': 320.79,
#   'low': 306.3,
#   'close': 308.83,
#   'volume': 19324495},
#  '2017-07-07': {'open': 313.5,
#   'high': 317.0,
#   'low': 307.38,
#   'close': 313.22,
#   'volume': 14176915},
#  '2017-07-10': {'open': 312.9,
#   'high': 317.94,
#   'low': 303.13,
#   'close': 316.05,
#   'volume': 13820889},
#  '2017-07-11': {'open': 316.0,
#   'high': 327.28,
#   'low': 314.3,
#   'close': 327.22,
#   'volume': 11559402},
#  '2017-07-12': {'open': 330.4,
#   'high': 333.1,
#   'low': 324.5,
#   'close': 329.52,
#   'volume': 10346127},
#  '2017-07-13': {'open': 330.11,
#   'high': 331.6,
#   'low': 319.97,
#   'close': 323.41,
#   'volume': 8594466},
#  '2017-07-14': {'open': 323.19,
#   'high': 328.42,
#   'low': 321.22,
#   'close': 327.78,
#   'volume': 5625211},
#  '2017-07-17': {'open': 325.54,
#   'high': 327.1,
#   'low': 313.45,
#   'close': 319.57,
#   'volume': 9876912},
#  '2017-07-18': {'open': 317.5,
#   'high': 329.13,
#   'low': 315.66,
#   'close': 328.24,
#   'volume': 6373720},
#  '2017-07-19': {'open': 328.23,
#   'high': 331.65,
#   'low': 323.22,
#   'close': 325.26,
#   'volume': 6357014},
#  '2017-07-20': {'open': 326.9,
#   'high': 330.22,
#   'low': 324.2,
#   'close': 329.92,
#   'volume': 5166188},
#  '2017-07-21': {'open': 329.46,
#   'high': 331.26,
#   'low': 325.8,
#   'close': 328.4,
#   'volume': 4901606},
#  '2017-07-24': {'open': 330.24,
#   'high': 343.4,
#   'low': 330.01,
#   'close': 342.52,
#   'volume': 8637082},
#  '2017-07-25': {'open': 345.0,
#   'high': 345.6,
#   'low': 334.15,
#   'close': 339.6,
#   'volume': 6989197},
#  '2017-07-26': {'open': 340.36,
#   'high': 345.5,
#   'low': 338.12,
#   'close': 343.85,
#   'volume': 4820790},
#  '2017-07-27': {'open': 346.0,
#   'high': 347.5,
#   'low': 326.29,
#   'close': 334.46,
#   'volume': 8302405},
#  '2017-07-28': {'open': 336.89,
#   'high': 339.6,
#   'low': 332.51,
#   'close': 335.07,
#   'volume': 4880414},
#  '2017-07-31': {'open': 335.5,
#   'high': 341.49,
#   'low': 321.04,
#   'close': 323.47,
#   'volume': 8535136},
#  '2017-08-01': {'open': 323.0,
#   'high': 324.45,
#   'low': 316.13,
#   'close': 319.57,
#   'volume': 8303102},
#  '2017-08-02': {'open': 318.94,
#   'high': 327.12,
#   'low': 311.22,
#   'close': 325.89,
#   'volume': 13091462},
#  '2017-08-03': {'open': 345.33,
#   'high': 350.0,
#   'low': 343.15,
#   'close': 347.09,
#   'volume': 13535033},
#  '2017-08-04': {'open': 347.0,
#   'high': 357.27,
#   'low': 343.3,
#   'close': 356.91,
#   'volume': 9268909},
#  '2017-08-07': {'open': 357.35,
#   'high': 359.48,
#   'low': 352.75,
#   'close': 355.17,
#   'volume': 6324480},
#  '2017-08-08': {'open': 357.53,
#   'high': 368.58,
#   'low': 357.4,
#   'close': 365.22,
#   'volume': 7449837},
#  '2017-08-09': {'open': 361.0,
#   'high': 370.0,
#   'low': 358.95,
#   'close': 363.53,
#   'volume': 6892096},
#  '2017-08-10': {'open': 361.6,
#   'high': 366.65,
#   'low': 354.66,
#   'close': 355.4,
#   'volume': 7092858},
#  '2017-08-11': {'open': 356.97,
#   'high': 361.26,
#   'low': 353.62,
#   'close': 357.87,
#   'volume': 4365783},
#  '2017-08-14': {'open': 364.63,
#   'high': 367.66,
#   'low': 362.6,
#   'close': 363.8,
#   'volume': 4519186},
#  '2017-08-15': {'open': 365.2,
#   'high': 365.49,
#   'low': 359.37,
#   'close': 362.33,
#   'volume': 3085088},
#  '2017-08-16': {'open': 363.0,
#   'high': 366.5,
#   'low': 362.52,
#   'close': 362.91,
#   'volume': 3413773},
#  '2017-08-17': {'open': 361.21,
#   'high': 363.3,
#   'low': 351.59,
#   'close': 351.92,
#   'volume': 5027660},
#  '2017-08-18': {'open': 352.91,
#   'high': 354.0,
#   'low': 345.8,
#   'close': 347.46,
#   'volume': 5408183},
#  '2017-08-21': {'open': 345.82,
#   'high': 345.82,
#   'low': 331.85,
#   'close': 337.86,
#   'volume': 6495424},
#  '2017-08-22': {'open': 341.13,
#   'high': 342.24,
#   'low': 337.37,
#   'close': 341.35,
#   'volume': 4321966},
#  '2017-08-23': {'open': 338.99,
#   'high': 353.49,
#   'low': 338.3,
#   'close': 352.77,
#   'volume': 4954504},
#  '2017-08-24': {'open': 352.52,
#   'high': 356.66,
#   'low': 349.74,
#   'close': 352.93,
#   'volume': 4584687},
#  '2017-08-25': {'open': 354.24,
#   'high': 355.69,
#   'low': 347.3,
#   'close': 348.05,
#   'volume': 3483956},
#  '2017-08-28': {'open': 347.28,
#   'high': 347.35,
#   'low': 339.72,
#   'close': 345.66,
#   'volume': 3763956},
#  '2017-08-29': {'open': 339.48,
#   'high': 349.05,
#   'low': 338.75,
#   'close': 347.36,
#   'volume': 4073675},
#  '2017-08-30': {'open': 349.67,
#   'high': 353.47,
#   'low': 347.0,
#   'close': 353.18,
#   'volume': 3412943},
#  '2017-08-31': {'open': 353.55,
#   'high': 358.44,
#   'low': 352.82,
#   'close': 355.9,
#   'volume': 4072795},
#  '2017-09-01': {'open': 356.12,
#   'high': 357.59,
#   'low': 353.69,
#   'close': 355.4,
#   'volume': 3049546},
#  '2017-09-05': {'open': 353.8,
#   'high': 355.49,
#   'low': 345.89,
#   'close': 349.59,
#   'volume': 3848382},
#  '2017-09-06': {'open': 349.5,
#   'high': 350.98,
#   'low': 341.56,
#   'close': 344.53,
#   'volume': 4091351},
#  '2017-09-07': {'open': 345.98,
#   'high': 352.48,
#   'low': 343.45,
#   'close': 350.61,
#   'volume': 4239213},
#  '2017-09-08': {'open': 348.99,
#   'high': 349.78,
#   'low': 342.3,
#   'close': 343.4,
#   'volume': 3263508},
#  '2017-09-11': {'open': 351.35,
#   'high': 363.71,
#   'low': 350.0,
#   'close': 363.69,
#   'volume': 7667055},
#  '2017-09-12': {'open': 364.49,
#   'high': 368.76,
#   'low': 360.4,
#   'close': 362.75,
#   'volume': 5972907},
#  '2017-09-13': {'open': 363.82,
#   'high': 368.07,
#   'low': 359.59,
#   'close': 366.23,
#   'volume': 4185231},
#  '2017-09-14': {'open': 364.33,
#   'high': 377.96,
#   'low': 362.63,
#   'close': 377.64,
#   'volume': 7202524},
#  '2017-09-15': {'open': 374.51,
#   'high': 380.0,
#   'low': 372.7,
#   'close': 379.81,
#   'volume': 5420496},
#  '2017-09-18': {'open': 380.25,
#   'high': 389.61,
#   'low': 377.68,
#   'close': 385.0,
#   'volume': 7187980},
#  '2017-09-19': {'open': 380.0,
#   'high': 382.39,
#   'low': 373.57,
#   'close': 375.1,
#   'volume': 6451886},
#  '2017-09-20': {'open': 373.0,
#   'high': 378.25,
#   'low': 371.07,
#   'close': 373.91,
#   'volume': 4919052},
#  '2017-09-21': {'open': 374.9,
#   'high': 376.83,
#   'low': 364.51,
#   'close': 366.48,
#   'volume': 4618190},
#  '2017-09-22': {'open': 366.49,
#   'high': 369.9,
#   'low': 350.88,
#   'close': 351.09,
#   'volume': 8159418},
#  '2017-09-25': {'open': 353.15,
#   'high': 357.47,
#   'low': 342.88,
#   'close': 344.99,
#   'volume': 7605946},
#  '2017-09-26': {'open': 350.93,
#   'high': 351.24,
#   'low': 340.9,
#   'close': 345.25,
#   'volume': 7156274},
#  '2017-09-27': {'open': 349.9,
#   'high': 351.49,
#   'low': 340.5,
#   'close': 340.97,
#   'volume': 6060330},
#  '2017-09-28': {'open': 339.88,
#   'high': 342.75,
#   'low': 335.4,
#   'close': 339.6,
#   'volume': 5319617},
#  '2017-09-29': {'open': 341.86,
#   'high': 344.68,
#   'low': 338.6,
#   'close': 341.1,
#   'volume': 5107082},
#  '2017-10-02': {'open': 342.52,
#   'high': 343.7,
#   'low': 335.51,
#   'close': 341.53,
#   'volume': 5286774},
#  '2017-10-03': {'open': 335.9,
#   'high': 348.55,
#   'low': 331.28,
#   'close': 348.14,
#   'volume': 10153596},
#  '2017-10-04': {'open': 351.25,
#   'high': 358.62,
#   'low': 349.6,
#   'close': 355.01,
#   'volume': 8163543},
#  '2017-10-05': {'open': 356.0,
#   'high': 357.44,
#   'low': 351.35,
#   'close': 355.33,
#   'volume': 4171675},
#  '2017-10-06': {'open': 353.1,
#   'high': 360.1,
#   'low': 352.25,
#   'close': 356.88,
#   'volume': 4297474},
#  '2017-10-09': {'open': 349.65,
#   'high': 351.75,
#   'low': 342.67,
#   'close': 342.94,
#   'volume': 7493654},
#  '2017-10-10': {'open': 346.8,
#   'high': 355.63,
#   'low': 345.53,
#   'close': 355.59,
#   'volume': 6978495},
#  '2017-10-11': {'open': 353.89,
#   'high': 357.6,
#   'low': 351.15,
#   'close': 354.6,
#   'volume': 4500831},
#  '2017-10-12': {'open': 352.95,
#   'high': 359.78,
#   'low': 352.64,
#   'close': 355.68,
#   'volume': 4087048},
#  '2017-10-13': {'open': 356.98,
#   'high': 358.49,
#   'low': 353.68,
#   'close': 355.57,
#   'volume': 3540533},
#  '2017-10-16': {'open': 353.76,
#   'high': 354.48,
#   'low': 347.16,
#   'close': 350.6,
#   'volume': 5375486},
#  '2017-10-17': {'open': 350.91,
#   'high': 356.22,
#   'low': 350.07,
#   'close': 355.75,
#   'volume': 3293345},
#  '2017-10-18': {'open': 355.97,
#   'high': 363.0,
#   'low': 354.13,
#   'close': 359.65,
#   'volume': 4939074},
#  '2017-10-19': {'open': 355.56,
#   'high': 357.15,
#   'low': 348.2,
#   'close': 351.81,
#   'volume': 5061843},
#  '2017-10-20': {'open': 352.69,
#   'high': 354.55,
#   'low': 344.34,
#   'close': 345.1,
#   'volume': 4930395},
#  '2017-10-23': {'open': 349.88,
#   'high': 349.95,
#   'low': 336.25,
#   'close': 337.02,
#   'volume': 5747346},
#  '2017-10-24': {'open': 338.8,
#   'high': 342.8,
#   'low': 336.16,
#   'close': 337.34,
#   'volume': 4491672},
#  '2017-10-25': {'open': 336.7,
#   'high': 337.5,
#   'low': 323.56,
#   'close': 325.84,
#   'volume': 8594073},
#  '2017-10-26': {'open': 327.78,
#   'high': 330.23,
#   'low': 323.2,
#   'close': 326.17,
#   'volume': 5023500},
#  '2017-10-27': {'open': 319.75,
#   'high': 324.59,
#   'low': 316.66,
#   'close': 320.87,
#   'volume': 6979704},
#  '2017-10-30': {'open': 319.18,
#   'high': 323.78,
#   'low': 317.25,
#   'close': 320.08,
#   'volume': 4254378},
#  '2017-10-31': {'open': 320.23,
#   'high': 331.95,
#   'low': 320.18,
#   'close': 331.53,
#   'volume': 5672347},
#  '2017-11-01': {'open': 332.25,
#   'high': 332.61,
#   'low': 320.26,
#   'close': 321.08,
#   'volume': 8457336},
#  '2017-11-02': {'open': 300.13,
#   'high': 308.69,
#   'low': 292.63,
#   'close': 299.26,
#   'volume': 19791416},
#  '2017-11-03': {'open': 299.5,
#   'high': 306.25,
#   'low': 295.13,
#   'close': 306.09,
#   'volume': 8893974},
#  '2017-11-06': {'open': 307.0,
#   'high': 307.5,
#   'low': 299.01,
#   'close': 302.78,
#   'volume': 6486009},
#  '2017-11-07': {'open': 301.02,
#   'high': 306.5,
#   'low': 300.03,
#   'close': 306.05,
#   'volume': 5294274},
#  '2017-11-08': {'open': 305.5,
#   'high': 306.89,
#   'low': 301.3,
#   'close': 304.39,
#   'volume': 4725271},
#  '2017-11-09': {'open': 302.5,
#   'high': 304.46,
#   'low': 296.3,
#   'close': 302.99,
#   'volume': 5447147},
#  '2017-11-10': {'open': 302.5,
#   'high': 308.36,
#   'low': 301.85,
#   'close': 302.99,
#   'volume': 4625429},
#  '2017-11-13': {'open': 300.13,
#   'high': 316.8,
#   'low': 299.11,
#   'close': 315.4,
#   'volume': 7584944},
#  '2017-11-14': {'open': 315.0,
#   'high': 316.35,
#   'low': 306.9,
#   'close': 308.7,
#   'volume': 5676076},
#  '2017-11-15': {'open': 306.01,
#   'high': 312.49,
#   'low': 301.5,
#   'close': 311.3,
#   'volume': 5978665},
#  '2017-11-16': {'open': 313.99,
#   'high': 318.14,
#   'low': 311.3,
#   'close': 312.5,
#   'volume': 5822073},
#  '2017-11-17': {'open': 325.67,
#   'high': 326.67,
#   'low': 313.15,
#   'close': 315.05,
#   'volume': 13735139},
#  '2017-11-20': {'open': 313.79,
#   'high': 315.5,
#   'low': 304.75,
#   'close': 308.74,
#   'volume': 8247650},
#  '2017-11-21': {'open': 310.86,
#   'high': 318.23,
#   'low': 308.71,
#   'close': 317.81,
#   'volume': 7261273},
#  '2017-11-22': {'open': 316.77,
#   'high': 317.42,
#   'low': 311.84,
#   'close': 312.6,
#   'volume': 4917636},
#  '2017-11-24': {'open': 313.79,
#   'high': 316.41,
#   'low': 311.0,
#   'close': 315.55,
#   'volume': 3244065},
#  '2017-11-27': {'open': 313.25,
#   'high': 317.34,
#   'low': 309.51,
#   'close': 316.81,
#   'volume': 4555894},
#  '2017-11-28': {'open': 316.36,
#   'high': 320.0,
#   'low': 313.92,
#   'close': 317.55,
#   'volume': 4949491},
#  '2017-11-29': {'open': 317.3,
#   'high': 318.0,
#   'low': 301.23,
#   'close': 307.54,
#   'volume': 8767398},
#  '2017-11-30': {'open': 308.56,
#   'high': 310.7,
#   'low': 304.54,
#   'close': 308.85,
#   'volume': 4351587},
#  '2017-12-01': {'open': 305.44,
#   'high': 310.32,
#   'low': 305.05,
#   'close': 306.53,
#   'volume': 4292868},
#  '2017-12-04': {'open': 306.5,
#   'high': 308.27,
#   'low': 300.61,
#   'close': 305.2,
#   'volume': 5835140},
#  '2017-12-05': {'open': 302.0,
#   'high': 308.0,
#   'low': 301.0,
#   'close': 303.7,
#   'volume': 4646520},
#  '2017-12-06': {'open': 300.1,
#   'high': 313.39,
#   'low': 300.0,
#   'close': 313.26,
#   'volume': 7195341},
#  '2017-12-07': {'open': 312.0,
#   'high': 318.63,
#   'low': 311.05,
#   'close': 311.24,
#   'volume': 4780597},
#  '2017-12-08': {'open': 314.6,
#   'high': 316.98,
#   'low': 311.26,
#   'close': 315.13,
#   'volume': 3468458},
#  '2017-12-11': {'open': 314.63,
#   'high': 329.01,
#   'low': 313.75,
#   'close': 328.91,
#   'volume': 7937981},
#  '2017-12-12': {'open': 330.45,
#   'high': 341.44,
#   'low': 330.03,
#   'close': 341.03,
#   'volume': 8733199},
#  '2017-12-13': {'open': 340.93,
#   'high': 344.22,
#   'low': 336.5,
#   'close': 339.03,
#   'volume': 6221461},
#  '2017-12-14': {'open': 341.01,
#   'high': 347.44,
#   'low': 336.9,
#   'close': 337.89,
#   'volume': 5799916},
#  '2017-12-15': {'open': 342.04,
#   'high': 343.9,
#   'low': 335.76,
#   'close': 343.45,
#   'volume': 6933199},
#  '2017-12-18': {'open': 344.9,
#   'high': 346.73,
#   'low': 337.58,
#   'close': 338.87,
#   'volume': 5476166},
#  '2017-12-19': {'open': 340.26,
#   'high': 341.49,
#   'low': 330.3,
#   'close': 331.1,
#   'volume': 6824971},
#  '2017-12-20': {'open': 332.69,
#   'high': 333.1,
#   'low': 325.04,
#   'close': 328.98,
#   'volume': 5953800},
#  '2017-12-21': {'open': 329.59,
#   'high': 333.74,
#   'low': 327.21,
#   'close': 331.66,
#   'volume': 4385222},
#  '2017-12-22': {'open': 329.51,
#   'high': 330.92,
#   'low': 324.82,
#   'close': 325.2,
#   'volume': 4215807},
#  '2017-12-26': {'open': 323.83,
#   'high': 323.94,
#   'low': 316.58,
#   'close': 317.29,
#   'volume': 4378413},
#  '2017-12-27': {'open': 316.0,
#   'high': 317.68,
#   'low': 310.75,
#   'close': 311.64,
#   'volume': 4712111},
#  '2017-12-28': {'open': 311.75,
#   'high': 315.82,
#   'low': 309.54,
#   'close': 315.36,
#   'volume': 4316347},
#  '2017-12-29': {'open': 316.18,
#   'high': 316.41,
#   'low': 310.0,
#   'close': 311.35,
#   'volume': 3777155}}

# %%
    # To obtain daily closing prices only (reduces message count), set close_only=True:
df = get_historical_data("TSLA", "20190617", close_only=True, token='pk_b740ad24ded147cca822e98ded174c3d')
df
# Out:
# {'2019-06-17': {'close': 225.03, 'volume': 12316803}}

# %%
    # For Pandas DataFrame output formatting, pass output_format:
df = get_historical_data("TSLA", start, end, output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')

# %%
    # It's really simple to plot this data, using matplotlib:
import matplotlib.pyplot as plt

df.plot()
plt.show()

# %% [markdown]
# #### Minutely (Intraday)
# * To obtain historical intraday data, use get_historical_intraday as follows.
# * Pass an optional date to specify a date within three months prior to the current day (default is current date):

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_intraday

date = datetime(2018, 11, 27)

get_historical_intraday("AAPL", date, token='pk_b740ad24ded147cca822e98ded174c3d')

# %%
    # or for a Pandas Dataframe indexed by each minute:

get_historical_intraday("AAPL", output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')

# %% [markdown]
# #### Real-time Quotes
# * To obtain real-time quotes for one or more symbols, use the get_price method of the Stock object:

# %%
from iexfinance.stocks import Stock
tsla = Stock('TSLA', token='pk_b740ad24ded147cca822e98ded174c3d')
tsla.get_price()
# Out:
# 667.99

# %% [markdown]
# ### Fundamentals

# %% [markdown]
# #### Balance Sheet

# %%
from iexfinance.stocks import Stock

aapl = Stock("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d')
aapl.get_balance_sheet()

# %% [markdown]
# #### Income Statement

# %%
aapl.get_income_statement()

# %% [markdown]
# #### Cash Flow

# %%
aapl.get_cash_flow()

# %% [markdown]
# #### Modeling/Valuation Tools
# * Analyst Estimates

# %%
from iexfinance.stocks import Stock

aapl = Stock("AAPL",, token='pk_b740ad24ded147cca822e98ded174c3d')

aapl.get_estimates()

# %% [markdown]
# #### Price Target

# %%
aapl.get_price_target()

# %% [markdown]
# #### Social Sentiment
# * iexfinance.altdata.get_social_sentiment(symbol, period_type=None, date=None, **kwargs)

# %%
from iexfinance.altdata import get_social_sentiment
get_social_sentiment("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d')

# %% [markdown]
# ####  CEO Compensation
# * iexfinance.altdata.get_ceo_compensation(symbol, **kwargs)

# %%
from iexfinance.altdata import get_ceo_compensation
get_ceo_compensation("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d')

# %% [markdown]
# ####  Fund and Institutional Ownership

# %%
from iexfinance.stocks import Stock
aapl = Stock("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d')

# Fund ownership
aapl.get_fund_ownership()

# Institutional ownership
aapl.get_institutional_ownership()

# %% [markdown]
# #### List of Symbols IEX supports for API calls

# %%
from iexfinance.refdata import get_symbols

get_symbols()

# %% [markdown]
# ### Account Usage

# %%
from iexfinance.account import get_usage

get_usage(quota_type='messages')

# %% [markdown]
# ### MORE DATA PULL OPTIONS

# %%
# Returns DataFrame of historical stock prices from symbols,
    # over date range, start to end. To avoid being
    # penalized by IEX servers, pauses between downloading 
    # ‘chunks’ of symbols can be specified.

pd.iex.daily.IEXDailyReader(symbols=None, start=None,end=None,
                            retry_count=3,pause=0.1, 
                            session=None, chunksize=25, api_key=None)

# %%
# Daily statistics from IEX for a day or month

pd.iex.stats.DailySummaryReader(symbols=None, start=None,
                             end=None, retry_count=3,
                             pause=0.1, session=None)

# %%
# Monthly statistics from IEX

pd.iex.stats.MonthlySummaryReader(symbols=None, start=None,
                                  end=None, retry_count=3,
                                  pause=0.1, session=None)

# %%
# Retrieve order book data from IEX

pd.iex.deep.Deep(symbols=None, service=None, start=None,
                 end=None, retry_count=3, pause=0.1, session=None)

# %%
start = datetime(2016, 9, 1)
end = datetime(2018, 9, 1)

IEX_API_KEY='pk_b740ad24ded147cca822e98ded174c3d'


f = web.DataReader('F', 'iex', start, end, api_key=IEX_API_KEY)

f=pd.DataFrame(f.loc['2018-08-31'])
f

# %%
f = web.DataReader('goog', 'iex-tops')
f[:10]

# %% [markdown]
# ## TINGO

# %%
pd.tiingo.TiingoDailyReader(symbols,start=None, end=None,
                            retry_count=3, pause=0.1,
                            timeout=30, session=None,
                            freq=None,api_key=None)

# %%
TIINGO_API_KEY='84d060da157bf79a157c6a9601dc46a28b62bc5c'

df = pdr.get_data_tiingo('GOOG', api_key=TIINGO_API_KEY)
df.head()

# %% [markdown]
# ## Alpha Vantage
# * Through the Alpha Vantage Time Series endpoints, it is possible to obtain historical equities data for individual symbols. For daily, weekly, and monthly frequencies, 20+ years of historical data is available. The past 3-5 days of
# * intraday data is also available.
# * Alpha vantage is used to get the minute level stock market data. You need to signup on alpha vantage to get the free API key.

# %%
# Import TimeSeries class
from alpha_vantage.timeseries import TimeSeries
ALPHA_VANTAGE_API_KEY = '0R9QKMGY0T17LR42'

# Initialize the TimeSeries class with key and output format
ts = TimeSeries(key=ALPHA_VANTAGE_API_KEY, output_format='pandas')

# Get pandas dataframe with the intraday data and information of the data
data, data_info=ts.get_daily('ACBI', outputsize ='compact')

# Print the information of the data
data_info
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'ACBI',
#  '3. Last Refreshed': '2020-02-28',
#  '4. Output Size': 'Compact',
#  '5. Time Zone': 'US/Eastern'}

# %%
# Print the intraday data
data.head()

# %%
data['4. close'].plot(figsize=(10, 7))

# Define the label for the title of the figure
plt.title("Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Time', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
# Returns DataFrame of the Alpha Vantage Stock Time Series endpoints

pd.av.time_series.AVTimeSeriesReader(symbols=None,
                                     function=’TIME_SERIES_DAILY’,
                                     start=None, end=None,
                                     retry_count=3,
                                     pause=0.1, session=None,
                                     chunksize=25,api_key=None)

# %%
# Returns DataFrame of the Alpha Vantage Sector Performances SECTOR data
pd.av.sector.AVSectorPerformanceReader(symbols=None,start=None,
                                       end=None,retry_count=3,
                                       pause=0.1, 
                                       session=None,api_key=None)

# %% [markdown]
# ### The following endpoints are available:
# * av-intraday - Intraday Time Series
# * av-daily - Daily Time Series
# * av-daily-adjusted - Daily Time Series (Adjusted)
# * av-weekly - Weekly Time Series
# * av-weekly-adjusted - Weekly Time Series (Adjusted)
# * av-monthly - Monthly Time Series
# * av-monthly-adjusted - Monthly Time Series (Adjusted)

# %%
# Historical Time Series Data

ALPHA_VANTAGE_API_KEY='1K573OJSLIUGLAGE'

tickers=['ACBI']

av_start=datetime(2017,1,1)
av_end=datetime(2020,1,1)

f = web.DataReader(tickers, "av-daily", start=av_start,end=av_end,
                   api_key=ALPHA_VANTAGE_API_KEY)

f
# Out:
#              open   high    low  close  volume
# 2017-01-03  19.10  19.20  18.75  18.90   95649
# 2017-01-04  19.05  19.15  19.00  19.15   50922
# 2017-01-05  19.10  19.40  19.00  19.30  113982
# 2017-01-06  19.40  19.65  19.35  19.65   54635
# 2017-01-09  19.55  19.75  19.55  19.70   60131
# ...           ...    ...    ...    ...     ...
# 2019-12-24  18.59  18.77  18.52  18.72   23513
# 2019-12-26  18.67  18.72  18.57  18.62   22988
# 2019-12-27  18.60  18.61  18.33  18.36   53920
# 2019-12-30  18.29  18.71  18.27  18.35   60706
# 2019-12-31  18.25  18.48  18.25  18.35   81207
#
# [754 rows x 5 columns]

# %%
f = web.DataReader(["USD/JPY", "BTC/CNY"], "av-forex",
                   api_key=ALPHA_VANTAGE_API_KEY)
f

# %% [markdown]
# ## YAHOO FINANCE (yfinance)
# One of the first sources from which you can get daily price-volume stock market data is Yahoo finance. You can use pandas_datareader or yfinance module to get the data.
#
# ####   Advantages
# Adjusted close price stock market data is available Most recent stock market data is available Doesn't require API key to fetch the stock market data
#
# #### Disadvantages
# It is not a stable source to fetch the stock market data If the stock market data fetching fails from yahoo finance using the pandas_datareader then you can use yfinance package to fetch the data.
#
# ##### yfinance is another module which can be used to fetch the minute level stock market data. It returns the stock market data for the last 7 days.
#
# The yfinance module has the download method which can be used to download the stock market data. It takes the following parameters:
#
# ticker: The name of the tickers you want the data for. If you want data for multiple tickers then separate them by space
#
# period: The number of days/month of data required. The valid frequencies are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max
#
# interval: The frequency of data. The valid intervals are 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo
#
# The below code fetches the stock market data for MSFT for the past 5 days of 1-minute frequency.

# %% [markdown]
# ##### Featured Methods
# get_financial_stmts(frequency, statement_type, reformat=True)
# frequency can be either ‘annual’ or ‘quarterly’.
# statement_type can be ‘income’, ‘balance’, ‘cash’ or a list of several.
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_stock_price_data(reformat=True)
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_stock_earnings_data(reformat=True)
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_summary_data(reformat=True)
# Returns financial summary data for cryptocurrencies, stocks, currencies, ETFs, mutual funds, U.S. Treasuries, commodity futures, and indexes.
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_stock_quote_type_data()
# get_historical_price_data(start_date, end_date, time_interval)
# This method will pull historical pricing data for stocks, currencies, ETFs, mutual funds, U.S. Treasuries, cryptocurrencies, commodities, and indexes.
# start_date should be entered in the ‘YYYY-MM-DD’ format and is the first day that data will be pulled for.
# end_date should be entered in the ‘YYYY-MM-DD’ format and is the last day that data will be pulled for.
# time_interval can be either ‘daily’, ‘weekly’, or ‘monthly’. This variable determines the time period interval for your pull.
# Data response includes relevant pricing event data such as dividends and stock splits.
# get_num_shares_outstanding(price_type=’current’)
# price_type can also be set to ‘average’ to calculate the shares outstanding with the daily average price.

# %% [markdown]
# ##### Additional Module Methods
# get_interest_expense()
# get_operating_income()
# get_total_operating_expense()
# get_total_revenue()
# get_cost_of_revenue()
# get_income_before_tax()
# get_income_tax_expense()
# get_gross_profit()
# get_net_income_from_continuing_ops()
# get_research_and_development()
# get_current_price()
# get_current_change()
# get_current_percent_change()
# get_current_volume()
# get_prev_close_price()
# get_open_price()
# get_ten_day_avg_daily_volume()
# get_three_month_avg_daily_volume()
# get_stock_exchange()
# get_market_cap()
# get_daily_low()
# get_daily_high()
# get_currency()
# get_yearly_high()
# get_yearly_low()
# get_dividend_yield()
# get_annual_avg_div_yield()
# get_five_yr_avg_div_yield()
# get_dividend_rate()
# get_annual_avg_div_rate()
# get_50day_moving_avg()
# get_200day_moving_avg()
# get_beta()
# get_payout_ratio()
# get_pe_ratio()
# get_price_to_sales()
# get_exdividend_date()
# get_book_value()
# get_ebit()
# get_net_income()
# get_earnings_per_share()
# get_key_statistics_data()

# %%
ydata = yf.download(tickers="MSFT",
 period="5d",
 interval="1m")
ydata.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2020-02-24 09:30:00-05:00  166.861893  166.861893  166.861893  166.861893
# 2020-02-24 09:31:00-05:00  166.889999  167.490005  165.639999  166.100006
# 2020-02-24 09:33:00-05:00  169.539993  169.600006  169.020004  169.020004
# 2020-02-24 09:34:00-05:00  169.220001  169.220001  169.220001  169.220001
# 2020-02-24 09:35:00-05:00  169.240005  169.990204  169.199997  169.990204
#
#                             Adj Close   Volume
# Datetime
# 2020-02-24 09:30:00-05:00  166.861893  6910973
# 2020-02-24 09:31:00-05:00  166.100006   521815
# 2020-02-24 09:33:00-05:00  169.020004  2146941
# 2020-02-24 09:34:00-05:00  169.220001   738616
# 2020-02-24 09:35:00-05:00  169.990204   698366

# %% [markdown]
# ###  Stocks Fundamental Data
# We have used yfinance to get the fundamental data.
#
# The first step is to set the ticker and then call the appropriate properties to get the right stock market data.

# %%
# Set the ticker as MSFT
# !pip install yfinance

# Import yfinance
import yfinance as yf

# Set the ticker as MSFT
y_finance = yf.Ticker("MSFT")


#yticker='MSFT'
#y_finance=yf.Ticker(yticker)

# %% [markdown]
# ### Key Ratios
# You can fetch the latest price to book ratio and price to earnings ratio as shown below.

# %%
# get price to book
pb = y_finance.info['priceToBook']
pe = y_finance.info['regularMarketPrice']/y_finance.info['trailingEps']

print('Price to Book Ratio is: %.2f' % pb)
print('Price to Earnings Ratio is: %.2f' % pe)
print('')

#or
ptb=y_finance.info['priceToBook']
print(ptb)

# %%
# show revenues

revenue = y_finance.info['enterpriseToRevenue']

revenue

#plt.bar(revenue.index, revenue.values)
#plt.ylabel("Total Revenues")
#plt.show()

# %%
# Earnings Before Interest and Taxes

EBIT = y_finance.info['enterpriseToEbitda']

EBIT

#plt.bar(EBIT,'years')
#plt.ylabel("EBIT")
#plt.show()

# %%
# show income statement
y_finance.financials

# show balance heet
y_finance.balance_sheet

# show cashflow
y_finance.cashflow

# show other info
y_finance.info

# %% [markdown]
# ### more data pulls

# %%
# Plot the adjusted close price
data['Adj Close'].plot(figsize=(10, 7))

# Define the label for the title of the figure
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
plt.show()

# %%
start = datetime(2016, 12, 31)
end = datetime.now()

stock_data = data.DataReader(["SBUX", "SHOP", "BIDU", "WDAY", "WIX",],
                             'yahoo', start, end)

stock_data=pd.DataFrame(stock_data['Adj Close'])
stock_data

# %%
stock_data_closing_prices = stock_data
stock_data_closing_prices.plot()
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price")
plt.title("Tech Stocks Adjusted Price Over Time")
plt.show()

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## Plot Portfolio

# %%
start = datetime(2016, 12, 31)
end = datetime.now()

stock_data = data.DataReader(["SBUX", "SHOP", "BIDU", "WDAY", "WIX",],
                             'yahoo', start, end)

stock_data=pd.DataFrame(stock_data['Adj Close'])
stock_data

# %%
stock_data_closing_prices = stock_data
stock_data_closing_prices.plot()
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price")
plt.title("Tech Stocks Adjusted Price Over Time")
plt.show()

# %%
stock_data_daily_returns = stock_data.pct_change()
stock_data_daily_returns.plot()
plt.xlabel("Date")
plt.ylabel("ROR")
plt.title("Daily Simple Rate of Return Over time")
plt.figure(figsize=(16,9))
plt.show()

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)



ax1.plot(stock_data['SBUX'].pct_change())
ax1.set_title("SBUX")
ax2.plot(stock_data['SHOP'].pct_change())
ax2.set_title("SHOP")
ax3.plot(stock_data['BIDU'].pct_change())
ax3.set_title("BIDU")
ax4.plot(stock_data['WDAY'].pct_change())
ax4.set_title("WDAY")
ax5.plot(stock_data['WIX'].pct_change())
ax5.set_title("WIX")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GRAPH DAILY MEAN

# %%
# calculate daily mean
daily_mean = stock_data_daily_returns.mean()
daily_mean1=pd.DataFrame(daily_mean)

# daily mean index for the x axis
daily_mean.keys()

# grab each daily mean value for the y axis
height = []
for key in daily_mean.keys():
    height.append(daily_mean[key])

# arrange keys on x axis based on length
x_pos = np.arange(len(daily_mean.keys()))


# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_mean.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("daily mean")
plt.title("daily mean rate of return")

# show graphic
plt.show()

daily_mean1

# %% [markdown]
# ## VARIANCE

# %%
# calculate variance
daily_var = stock_data_daily_returns.var()
daily_var1=pd.DataFrame(daily_var)

# variance index for the x axis
daily_var.keys()

# grab each variance value for the y axis
height = []
for key in daily_var.keys():
    height.append(daily_var[key])
    
# arrange keys on x axis based on length
x_pos = np.arange(len(daily_var.keys()))



# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_var.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("variance")
plt.title("daily variance")

# show graphic
plt.show()

daily_var1

# %% [markdown]
# ## STANDARD DEVIATION (STD)

# %%
# calculate standard deviation
daily_std = stock_data_daily_returns.std()
daily_std1=pd.DataFrame(daily_std)

# standard deviation index for the x axis
daily_var.keys()

# grab each standard deviation value for the y axis
height = []
for key in daily_std.keys():
    height.append(daily_std[key])
    
# arrange keys on x axis based on length
x_pos = np.arange(len(daily_std.keys()))


# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_std.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("std")
plt.title("daily std")

# show graphic
plt.show()

daily_std1

# %% [markdown]
# # RATIO ANALYSIS
# * some short description about this section
#
# 1. Daily Mean
#     -
# 2. Concept
# 3. concept

# %% [markdown]
# ## DAILY MEAN RoR

# %%
# calculate daily mean
daily_mean = stock_data_daily_returns.mean()
daily_mean1=pd.DataFrame(daily_mean)

daily_mean1

# %% [markdown]
# ## variance

# %%
# calculate variance
daily_var = stock_data_daily_returns.var()
daily_var1=pd.DataFrame(daily_var)
daily_var1

# %% [markdown]
# ## Standard Deviation

# %%
# calculate standard deviation
daily_std = stock_data_daily_returns.std()
daily_std1=pd.DataFrame(daily_std)
daily_std1

# %% [markdown]
# ## PORTFOLIO CORRELATION

# %%
stock_data_daily_returns.corr()

# %% [markdown]
# # STRATEGIES

# %% [markdown]
# ## PAIRS TRADING STRATEGY

# %%
# Initializing variables

data = []
headers = ['Date','commodity1','commodity2','zscore','signal','status',\
              'buy price','sell price','mtm','pnl','Cointegration test']
data.append(headers)
threshold = 1.75    # Tolerance for the stdev above and below the mean
start=80
end=90
prev_status = ""
mtm = ""
prev_sell_price = ""
sell_price = ""
prev_buy_price = ""
buy_price = ""
SL = -10000      # Stop loss
TP = 20000       # Take profit
N=5000           # Lot size for data1
M=5000           # Lot size for data2

# %%
from quantrautil import get_quantinsti_api_key

# To get your API key, sign up for a free Quandl account.
# Then, you can find your API key on Quandl account settings page.

key = get_quantinsti_api_key()

data1 = quandl.get("CHRIS/MCX_AL1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= key)
data2 = quandl.get("CHRIS/MCX_PB1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= key)

# %%
QUANDL_API_KEY = 'VpYKj-e3pTXsUxQBMcto'

# Set the start and end date
start_date = '1990-01-01'
end_date = '2018-03-01'

# Set the ticker name
ticker = 'AMZN'

# Feth the data
data1 = quandl.get("CHRIS/MCX_AL1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= QUANDL_API_KEY)
data2 = quandl.get("CHRIS/MCX_PB1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= QUANDL_API_KEY)


# Print the first 5 rows of the dataframe
data

# %%
# Drop nan columns
data1 = data1.dropna()
data2 = data2.dropna()

# To make the data uniform date wise
data1['key']=data1.index
data2['key']=data2.index

# Merge dataframes to find common dates
result = pd.merge(data1, data2, on='key', left_index=True, right_index=False)

data1 = result[['Open_x','High_x','Low_x','Close_x','Volume_x']] 
data2 = result[['Open_y','High_y','Low_y','Close_y','Volume_y']]

data1.columns = ['Open','High','Low','Close','Volume'] # Rename the columns

data2.columns = ['Open','High','Low','Close','Volume'] # Rename the columns

# %%
# Define cointegration test function

# Use OLS method to find the spread of the two series
# Check for stationarity of the spread using adfuller test

def cointegration_test(x, y):
    result = stat.OLS(x['Close'], y['Close']).fit()   
    return ts.adfuller(result.resid)

# %%
# Define z-score calculation function
def zscore_cal(data1,data2,start,end):
    s1 = pd.Series(data1['Close'][start:end])
    s2 = pd.Series(data2['Close'][start:end])

    mvavg_old = np.mean(np.log(s1/s2))  # Compute mean of the spread till now

    std_old = np.std(np.log(s1/s2))    #  Compute stdev of the spread till now
    
    current_spread = np.log(data1['Close'][end]/data2['Close'][end])   # Compute spread
    
    # This is the same as current_spread = np.log(data1['Close'][end]) - np.log(data2['Close'][end])
    
    zscore = (current_spread - mvavg_old)/std_old if std_old > 0 else 0  # Compute z-score

    return zscore

# %%
# Generating trading signals
def signal_cal(zscore,threshold,adftest):
    if zscore > threshold and adftest == 'Yes': 
        signal = 'SELL' # Z-score is greater than threshold, the spread shall fall towards mean

    elif zscore < -threshold and adftest == 'Yes':
        signal = 'BUY' # Z-score is smaller than threshold, the spread shall rise towards mean
    else:
        signal = ''
    return signal

# %%
# Defining status
def status_cal(prev_status,mtm,SL,TP,signal,adftest):
    if prev_status in ["","SL","TP","CB"]:
        status = signal
    else:
        if adftest == "No":
            status = "CB"   # Break in the cointegration status of the pair
        else:
            if mtm == "":
                status = ""
            else:
                if mtm<SL:
                    status="SL"   # Stop loss status
                else:
                    if mtm>TP:
                        status="TP"  # Take profit status
                    else:
                        status = prev_status

    return status

# %%
# Calculating buy price
def buy_price_cal(prev_status,prev_buy_price,buy_price,signal,status,data1, data2,end):
    if status == prev_status:
        buy_price = prev_buy_price
    else:
        if status in ["SL","TP","CB",""]:
            buy_price = ""
        else:
            if signal == "BUY":    # Signal is to buy the spread
                buy_price = data1['Close'][end]  # Hence, buy price = close of first security
            else:
                if signal == "SELL":  # Signal is to sell the spread
                    buy_price = data2['Close'][end]  # Hence, buy price = close of second security
                else:
                    buy_price = ""   # no signal hence no buy price

    return buy_price

# %%
# Calculating sell price
def sell_price_cal(prev_status,prev_sell_price,sell_price,signal,status, data1,data2,end):
    if status == prev_status:
        sell_price = prev_sell_price
    else:
        if status in ["SL","TP","CB",""]:
            sell_price = ""
        else:
            if signal == "BUY":  # Signal is to buy the spread
                sell_price = data2['Close'][end] # Hence sell price = close of second security
            else:
                if signal == "SELL": # signal is to sell the spread
                    sell_price = data1['Close'][end] # Hence sell price = close of first security
                else:
                    sell_price = "" # No signal hence no sell price either

    return sell_price

# %%
# Calculating mtm
def mtm_cal(data1,data2,prev_status,prev_sell_price,prev_buy_price,M,N,end):
    if prev_status == "BUY":
        mtm = (prev_sell_price-data2['Close'][end])*M + (data1['Close'][end]-\
               prev_buy_price)*N  # Calculate mtm of the trades using their lot sizes
    else:
        if prev_status == "SELL":
            mtm =(prev_sell_price-data1['Close'][end])*N +(data2['Close'][end]\
                   -prev_buy_price)*M    # Calculate mtm of the trades using their lot sizes
        else:
            mtm = ""

    return mtm

# %%
# Defining the strategy function to execute the pairs trading program
def strategy(data1,data2,threshold,start,end,prev_status,mtm,prev_sell_price,\
             sell_price,prev_buy_price,buy_price,SL,TP,M,N):
    pnl = 0
    i = 0
    for row in data1[90:].iterrows():

         # Running the ADF test for each day, starting from day 91
        d1 = data1[i:90+i]
        d2 = data2[i:90+i]
        c_t = cointegration_test(d1, d2)
        if c_t[0] <= c_t[4]['10%'] and c_t[1] <= 0.1:
            adftest = "Yes"
        else:
            adftest = "No"
   
        # Calculating z-score
        zscore = zscore_cal(data1,data2,start,end)

        # Generating trading signals
        signal = signal_cal(zscore,threshold,adftest)

        # Calculating mtm
        mtm = mtm_cal(data1,data2,prev_status,prev_sell_price,\
                      prev_buy_price,M,N,end)

        # Assigning status
        status = status_cal(prev_status,mtm,SL,TP,signal,adftest)

        # Assigning buy_price
        buy_price = buy_price_cal(prev_status,prev_buy_price,buy_price,\
                                  signal,status,data1,data2,end)


        # Assigning sell_price
        sell_price = sell_price_cal(prev_status,prev_sell_price,sell_price,\
                                    signal,status,data1,data2,end)

        # Calculating pnl
        pnl = (pnl + mtm) if status in ["TP","SL","CB"] else pnl

        # Assigning prev values
        prev_sell_price = sell_price
        prev_status = status
        prev_buy_price = buy_price

        # Appending calculations to the data array
        data.append([str(data1.index[end])[:10],data1['Close'][end],\
                         data2['Close'][end],zscore,signal,status,buy_price,\
                         sell_price,mtm,pnl,adftest])

        # Incrementing variables to consider the next set of data
        end = end+1
        start = start+1
        i = i+1
        
    pyexcel.save_as(array = data, dest_file_name = \
                        'pair_strategy_without_zipline-90.csv')  # Save to CSV for debugging

# %%
fig,ax = plt.subplots(1,1,figsize = (10,5))

# Plot data1.Close
ax.plot(data1.index, data1.Close, label ='Aluminium') 

# Plot data2.Close
ax.plot(data2.index, data2.Close, label ='Lead') 

plt.legend() # Let matplotlib choose best location for legend
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Close Prices', fontsize = 20)
plt.title('Aluminium and Lead Close Prices', fontsize = 20)

plt.grid() # Display the major grid
plt.tight_layout()
plt.show() # Finally display the plot

# %%
fig,ax = plt.subplots(1,1,figsize = (10,5))

# Plot the spread
ax.plot(data2.index, np.log(data1.Close.values/data2.Close.values), label = 'Spread') 

plt.legend()
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Spread', fontsize = 20)
plt.title('Spread of Aluminium and Lead Close Prices', fontsize = 20)
plt.grid() 
plt.tight_layout()
plt.show()

# %%
# Run the strategy
strategy(data1,data2,threshold,start,end,prev_status,mtm,prev_sell_price,\
             sell_price,prev_buy_price,buy_price,SL,TP,M,N) 

result = pd.DataFrame(data, columns=headers)[1:] # Ignore the first row
result.set_index('Date',inplace=True)  # Set Date column as index for better plotting
result.index = pd.to_datetime(result.index) # Convert index to a datetime index

result.pnl.plot(figsize=(10,5), label ='PnL') 
plt.legend() 
plt.ylabel('PnL')
plt.title('PnL')
plt.grid() 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## INCOME STMT ANALYSIS (with waterfall chart)

# %%
def selectquote(quote): 
    r= requests.get(f"https://financialmodelingprep.com/api/v3/financials/income-statement/{quote}?period=quarter") 
    r = r.json() 
    stock = r['financials']
    stock = pd.DataFrame.from_dict(stock) 
    stock = stock.T   
    stock.columns = stock.iloc[0]
    stock.reset_index(inplace=True) 
    return stock 

selectquote('AAPL')

# %%
def selectquote1(quote):
    r= requests.get(f"https://financialmodelingprep.com/api/v3/financials/income-statement/{quote}?period=quarter")
    r = r.json()
    stock = r['financials']
    stock = pd.DataFrame.from_dict(stock)
    stock = stock.T
    stock.columns = stock.iloc[0]
    stock.reset_index(inplace=True)
    stock = stock.iloc[:,0:2]
    stock.rename(columns={ stock.columns[1]: quote }, inplace = True)
    cols = stock.columns.drop('index')
    stock = stock.iloc[1:,]
    return stock

selectquote1('AAPL')

# %%
r=requests.get("https://financialmodelingprep.com/api/v3/financials/income-statement/AAPL?period=quarter")
r=r.json()
d=r['financials']
count=0
for item in d:
    if count ==0:
        d=r['financials']
        d=d[0]
        incomeinitial=pd.DataFrame(list(d.items()),columns=['item','value'])
    count=count+1
    if count>5:
        continue
    d=r['financials']
    d=d[count]
    
    incomeinitial2=pd.DataFrame(list(d.items()),columns=['item','value'])
    incomeinitial=incomeinitial.merge(incomeinitial2,on="item",how='left')
    
incomeinitial=pd.DataFrame(list(d.items()),columns=['item','value'])
incomeinitial.columns=incomeinitial.iloc[0]
incomeinitial=incomeinitial[1:]
incomeinitial
cols=incomeinitial.columns
cols=cols[1:]

# %%
Revenue = incomeStatement[incomeStatement['index'] == 'Revenue'].iloc[0][1]
COGS = incomeStatement[incomeStatement['index'] == 'Cost of Revenue'].iloc[0][1]*-1
grossProfit = incomeStatement[incomeStatement['index'] == 'Gross Profit'].iloc[0][1] 
RD = incomeStatement[incomeStatement['index'] == 'R&D Expenses'].iloc[0][1]*-1 
GA = incomeStatement[incomeStatement['index'] == 'SG&A Expense'].iloc[0][1]*-1
operatingExpenses = incomeStatement[incomeStatement['index'] == 'Operating Expenses'].iloc[0][1]*-1 
interest = incomeStatement[incomeStatement['index'] == 'Interest Expense'].iloc[0][1]*-1
EBT = incomeStatement[incomeStatement['index'] == 'Earnings before Tax'].iloc[0][1]
incTax = incomeStatement[incomeStatement['index'] == 'Income Tax Expense'].iloc[0][1]*-1
netIncome = incomeStatement[incomeStatement['index'] == 'Net Income'].iloc[0][1]

# %%
fig = go.Figure(go.Waterfall(
    name = "20", orientation = "v",
    measure = ["relative", "relative", "total", "relative", "relative", "total","relative","total","relative","total"],

    x = ["Revenue", "COGS", "Gross Profit", "RD", "G&A", "Operating Expenses","Interest Expense", "Earn Before Tax","Income Tax","Net Income"],
    textposition = "outside",

    text = [Revenue/100000, COGS/100000, grossProfit/100000, RD/100000, GA/1000000, operatingExpenses/1000000,Interest/100000, EBT/100000,incTax/100000, NetIncome/100000],

     y = [Revenue, COGS, grossProfit, RD, GA, operatingExpenses, Interest,EBT,incTax,NetIncome],

    connector = {"line":{"color":"rgb(63, 63, 63)"}},
     
fig.update_layout(
         title = "Profit and loss statement",
         showlegend = True
 )))

fig.show()

# %%
print('Here Is The Financial Report For: AAPL')
incomeinitial

# %% [markdown]
# ## Portfolio Allocation and Sharp Ratio

# %%
# . . . . . . . . . . DEFINE 5 SECURITIES TO LOOKUP . . . . . . . . . .
s1=input('Enter Ticker 1: ')
s2=input('Enter Ticker 2: ')
s3=input('Enter Ticker 3: ')
s4=input('Enter Ticker 4: ')

# . . . . . . . . . . ASSIGN ASSETS TO LONG STRING 'STOCKS' . . . . . . . . . .
stocks=(s1+'_'+s2+'_'+s3+'_'+s4)

# %%
start = datetime(2015, 1, 1)
end = datetime.now()

quandl.ApiConfig.api_key = 'zdZRZgzAuK8P2AnsZhU3'
data_df_1 = quandl.get('WIKI/' + s1+'.11', start_date=start, end_date=end, api_key = 'zdZRZgzAuK8P2AnsZhU3')
data_df_2 = quandl.get('WIKI/' + s2+'.11', start_date=start, end_date=end, api_key = 'zdZRZgzAuK8P2AnsZhU3')
data_df_3 = quandl.get('WIKI/' + s3+'.11', start_date=start, end_date=end, api_key = 'zdZRZgzAuK8P2AnsZhU3')
data_df_4 = quandl.get('WIKI/' + s4+'.11', start_date=start, end_date=end, api_key = 'zdZRZgzAuK8P2AnsZhU3')


data_price_1 = data_df_1['Adj. Close'].values
data_np_1 = data_df_1.values

data_price_2 = data_df_2['Adj. Close'].values
data_np_2 = data_df_2.values

data_price_3 = data_df_3['Adj. Close'].values
data_np_3 = data_df_3.values

data_price_4 = data_df_4['Adj. Close'].values
data_np_4 = data_df_4.values


data_df_1.to_csv(r'C:\Users\gordo\CODE_BUILDING\Real_Time_Stock_Market_Data\Portfolio_Allocation_Sharp_Ratio\quandl_data_'+s1+'.csv')
data_df_2.to_csv(r'C:\Users\gordo\CODE_BUILDING\Real_Time_Stock_Market_Data\Portfolio_Allocation_Sharp_Ratio\quandl_data_'+s2+'.csv')
data_df_3.to_csv(r'C:\Users\gordo\CODE_BUILDING\Real_Time_Stock_Market_Data\Portfolio_Allocation_Sharp_Ratio\quandl_data_'+s3+'.csv')
data_df_4.to_csv(r'C:\Users\gordo\CODE_BUILDING\Real_Time_Stock_Market_Data\Portfolio_Allocation_Sharp_Ratio\quandl_data_'+s4+'.csv')

# %%
for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[0]['Adj. Close']
#print(s1)
#data_df_1

for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[1]['Adj. Close']

#print(s2)
#data_df_2

for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[2]['Adj. Close']

#print(s3)
#data_df_3

for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[3]['Adj. Close']

#print(s4)
#data_df_4

# %%
# INPUT ALLOCATIONS PER ASSET

s1_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s1_a=float(s1_allocate)

s2_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s2_a=float(s2_allocate)

s3_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s3_a=float(s3_allocate)

s4_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s4_a=float(s4_allocate)

# %%
for df_stock,allocation in zip([data_df_1,data_df_2,data_df_3,data_df_4],[s1_a,s2_a,s3_a,s4_a]):
    df_stock['Allocation'] = df_stock['Normalize Return']*allocation

# %%
#print(s1)
#data_df_1

# %%
for df_stock in [data_df_1,data_df_2,data_df_3,data_df_4]:
    df_stock['Position Values'] = df_stock['Allocation']*10000

# %%
print(s1)
data_df_1

# %%
portfolio_val = pd.concat([data_df_1['Position Values'],data_df_2['Position Values'],data_df_3['Position Values'],data_df_4['Position Values']],axis=1)

# %%
portfolio_val.columns = [s1,s2,s3,s4]
portfolio_val

# %%
portfolio_val['Total Pos'] = portfolio_val.sum(axis=1)
portfolio_val

# %%
portfolio_val['Total Pos'].plot(figsize=(10,8))
plt.title('Total Portfolio Value')

# %%
portfolio_val.drop('Total Pos',axis=1).plot(kind='line')

# %% [markdown]
# ## Quantitative Value Strategy

# %% [markdown]
# ### Define The Method To Extract Fundamental Data

# %%
def get_fundamental_data(df):
    for symbol in df.index:

        url = ("http://finviz.com/quote.ashx?t=" + symbol.lower())
        soup = bs(requests.get(url).content)  # , features='html5lib')
        for m in df.columns:
            try:
                df.loc[symbol, m] = fundamental_metric(soup, m)
            except Exception as e:
                print(symbol, 'not found')
                print(e)
                break
    return df

# %%
def fundamental_metric(soup, metric):
    return soup.find(text=metric).find_next(class_='snapshot-td2').text

# %% [markdown]
# ### Define A List Of Stocks And The Fundamental Metrics

# %%
stock_list = ['AMZN', 'GOOG', 'AXL', 'FB', 'TSLA', 'WMT', 'DIS','KO', 'PEP', '', 'FICO', 'AMD', 'IBM', 'AAPL', 'LPL']

metric = ['P/B',
'P/E',
'Forward P/E',
'PEG',
'Debt/Eq',
'EPS (ttm)',
'Dividend %',
'ROE',
'ROI',
'EPS Q/Q',
'Insider Own'
]

# %%
df = pd.DataFrame(index=stock_list,columns=metric)
df = get_fundamental_data(df)

print('')
print("All stocks with fundamental data")

df

# %% [markdown]
# ### Businesses which are quoted at low valuations
# * P/E < 20
# * P/B < 3

# %%
try:
    df = df[(df['P/E'].astype(float) < 20) & (df['P/B'].astype(float) < 3)]
except:
    pass

# %% [markdown]
# ### Businesses which have demonstrated earning power
# * EPS Q/Q > 10%

# %%
try:
    df['EPS Q/Q'] = df['EPS Q/Q'].map(lambda x: x[:-1])
    df = df[df['EPS Q/Q'].astype(float) > 10]
except:
    pass

# %% [markdown]
# ### Businesses earning good returns on equity while employing little or no debt
# * Debt/Eq < 1
# * ROE > 10%

# %%
try:
    df['ROE'] = df['ROE'].map(lambda x: x[:-1])
    df = df[(df['Debt/Eq'].astype(float) < 1) & (df['ROE'].astype(float) > 10)]
except:
    pass

# %% [markdown]
# ### Management having substantial ownership in the business
# * Insider own > 30%

# %%
try:
    df['Insider Own'] = df['Insider Own'].map(lambda x: x[:-1])
    df = df[df['Insider Own'].astype(float) > 30]
except:
    pass

print("Stocks after screening")
df

# %% [markdown]
# # ALPHA & BETA MARKET ANALYSIS

# %%
start='2019-1-1'
end='2020-1-1'

yf.pdr_override()

df1=pdr.get_data_yahoo("GOOG", start, end)
df2=pdr.get_data_yahoo("SPY", start, end)

df1
#df2

# %% [markdown]
# ## GOAL = Obtain Percent Change [.pct_change()]
# Also, do NOT want to obtain first (0th) element because that will result in NaN

# %%
return_goog=df1.Close.pct_change()[1:]
return_spy=df2.Close.pct_change()[1:]

# %% [markdown]
# ## PLOT Returns Versus
# We will plot the returns of Google and S&P500 against each other

# %%
plt.figure(figsize=(20,10))
return_goog.plot()
return_spy.plot()
plt.ylabel("Daily Return of GOOG and SPY")
plt.show()

# %% [markdown]
# ## Capital Asset Pricing Model or CAPM (How to Calculate Beta)
# * One of the most common ways to calculate beta is using the Capital Asset Pricing Model or CAPM.
# - Have a look at the CAPM model:
#     - E (Ra) = Rf + Ba [ E (Rm) - Rf]
#
# * CAPM model states that the expected return of an asset ‘E (Ra)’ is equal to the risk-free return in the market plus the difference between the expected return of the market and risk-free rate ‘[E (Rm) - Rf]’ multiplied by the asset’s beta  ‘Ba’.
#
# * If we have all the values except the asset’s beta, we can calculate the beta using:
#        -  Ba = [E (Ra) - Rf] / [ E (Rm) - Rf]
#
# * We can even find beta by performing the ‘regression analysis’.
#
# * When one tries to capture a mathematical relationship between ‘x’ and ‘y’ variables, by fitting a line, polynomial or a curve through scatter plots, such that one can make a reasonably good prediction of  ‘y’ given ‘x’, then the mathematical process of deriving such an equation between x and y is called the regression analysis.This equation can also arrived at by using a machine learning based regression model.
#
# * If we try to fit a ‘line’ through this scatter plot that “best” explains the observed values of ‘y’ in terms of observed values of ‘x’, we get a simple linear regression model.
#
# * Linear regression assumes a linear relationship between the dependent and independent variables.
#
# * The following regression equation describes that relation:
#     - Yi = b0 + b1 Xi + ei
#
# * We refer to the intercept ‘b0’ and slope coefficient ‘b1’ as the regression coefficients and ei as the random error.
#     - Rasset = ex-post alpha + beta of asset *  Rbenchmark  + ei
#
# * To understand the coefficients more intuitively, if we consider the returns for Google vs. S&P 500 index, then the slope coefficient in a regression line is called the stock’s beta, as it measures the relative amount of systematic or undiversifiable risk in Google’s returns.
#
# * If the slope of Google returns is more than 1, its returns tend to increase or decrease more than the market returns. A slope or beta of 1 would have the same level of systematic risk as that of the market on an average, and a slope or beta less than 1 implies that the returns increase or decrease by less than the change in the market returns.
#
# * The intercept term is the ex-post alpha i.e. the measure of excess returns of Google as compared to market index returns. If the intercept term is negative, it means Google has underperformed S&P on a risk adjusted basis and a positive intercept means it has had excess returns on risk adjusted basis.
#
# * All the points on the regression equation line, predict the ‘y’ values for the corresponding ‘x’ values. However, the optimal regression line is the one for which the sum of the squared differences (vertical distances) or the sum of squared errors or SSE between the ‘y’ values predicted by the regression equation/line and the actual ‘y’ values is minimal.
#
# * Thus, the regression line minimizes the SSE. This is the reason why simple linear regression is also called as Ordinary Least Squares or OLS, and the estimated (predicted) values by the regression equation i.e. y predicted are called least squares estimates.
#
# * The slope coefficient ‘b1’ of the regression line is calculated as the covariance of x and y divided by the variance of x (covxy /σ2x ), and the intercept coefficient is the line's intersection with the y axis at x = 0.

# %%
import statsmodels.api as sm
from statsmodels import regression

X=return_spy.values
Y=return_goog.values

def linreg(x,y):
    x=sm.add_constant(x)
    model=regression.linear_model.OLS(y,x).fit()
    
    # REMOVE THE CONSTANT
    x=x[:,1]
    return model.params[0], model.params[1]

alpha, beta = linreg(X,Y)
print('alpha: '+str(alpha))
print('')
print('beta: '+str(beta))

# %% [markdown]
# ## LINEAR REGRESSION PLOT

# %%
X2 = np.linspace(X.min(), X.max(), 100)
Y_hat = X2 * beta + alpha

plt.figure(figsize=(10,7))
plt.scatter(X, Y, alpha=0.3) # PLOTS RAW DATA

plt.xlabel('S&P 500 Daily Return')
plt.ylabel('GOOG Daily Return')

plt.plot(X2, Y_hat, 'r', alpha=0.9)

plt.show()
